# %%
#get dependencies
import numpy as np
from pyyoutube import Api
import requests as req
import re
import pandas as pd
import glob
from datetime import datetime, timezone
import logging as log
from progress.bar import Bar
import yaml
from lyricsgenius import Genius

with open("config.yaml") as config_file:
    config = yaml.load(config_file.read())

VERBOSE = False
START_YEAR = 2014
END_YEAR = 2016
# Out:
# <ipython-input-8-952cce5eee69>:15: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(config_file.read())

# %%
# authenticate for spotify
spotify_auth = (config["spotify"]["client-id"],config["spotify"]["client-secret"])
token_res = req.post(   'https://accounts.spotify.com/api/token', 
                        auth=spotify_auth,
                        headers={
                            'content-type': 'application/x-www-form-urlencoded'
                        },
                        data={'grant_type': 'client_credentials'}
                    )
spotify_token = token_res.json()['access_token']

# authenticate for youtube 
youtube_api_key = config["youtube"]["api-key"]
yt = Api(api_key=youtube_api_key)

genius_access_token = config["genius"]["access-token"]
genius = Genius(genius_access_token)

# %%
res = yt.get_channel_info(channel_name="theneedledrop")
print(res)
tnd_id = res.items[0].id

#note: youtubes api limits to 500 videos per search.



for yr in range(START_YEAR,END_YEAR+1):

    print("collecting data for " + str(yr))
    albums = pd.DataFrame(
    {'spotify_id':[],
    'youtube_id':[],
    'project_name':[],
    'artist':[],
    'project_type':[],
    'tracks':[],
    'project_art':[],
    'year':[],
    'rating':[]})


    tracks = pd.DataFrame(
        {'spotify_id':[],
            'album_id':[],
            'youtube_id':[],
            'name':[],
            'duration':[],
            'explicit':[],
            'preview':[],
            'key':[],
            'mode':[],
            'acousticness':[],
            'danceability':[],
            'energy':[],
            'instrumentalness':[],
            'liveness':[],
            'loudness':[],
            'speechiness':[],
            'valence':[],
            'tempo':[]})

    published_before_ts = datetime(yr+1,1,1,tzinfo=timezone.utc).isoformat()
    published_after_ts = datetime(yr,1,1,tzinfo=timezone.utc).isoformat()

    review_vids = yt.search(parts='id,snippet',
                            search_type='video',
                            channel_id=tnd_id, 
                            q='REVIEW',
                            count=500,
                            limit=500,
                            published_after=published_after_ts,
                            published_before=published_before_ts)

    bar = Bar("Processing videos", max=len(review_vids.items))
    for item in review_vids.items:

        album = {}

        vid_id = item.id.videoId
        vid = yt.get_video_by_id(video_id=vid_id).items[0]
        description = vid.snippet.description
        vid_title = vid.snippet.title.lower().split(" ")
        if 'review' not in vid_title:
            print("invalid title: " + vid.snippet.title)
            continue
        
        review_index = len(vid_title) - vid_title[::-1].index('review') - 1

        if vid_title[vid_title.index('review') - 1] in ['album','mixtape','ep','redux','complimation','soundtrack','track']:
            project_type = vid_title[review_index - 1]

            type_index = review_index - 1

            project_info = " ".join(vid_title[:type_index]).split("- ")
        else:
            project_info = " ".join(vid_title[:review_index]).split("- ")

        if len(project_info) < 2:
            print("invalid title: " + vid.snippet.title)
            continue
        artist = project_info[0].strip()
        project_name = "-".join(project_info[1::]).strip()
        rating_regex = re.search(r'\d+/10',description)
        if rating_regex:
            rating = int(rating_regex.group(0)[0:1])
        else:
            print("no rating: " + vid.snippet.title)
            continue

        

        # spotify has trouble picking up artists with ampersands in their names as well as 
        # self-titled albums, so fix the query to eliminate those errors
        search_term = ""

        search_term += " ".join(artist.replace("[","").replace("]","").replace(" X "," ").split(" & ")) + " "

        if "self-titled" in project_name:
            search_term += " " + artist
        else:
            search_term += project_name.replace("[","").replace("]","")

        if VERBOSE:
            print("searching for: " + search_term)
        

        search_res = req.get(   'https://api.spotify.com/v1/search',
                            params={
                                'q': search_term,
                                "type": "album",
                                "limit": 1,
                                'include_external': True
                            },
                            headers={
                                'authorization': "Bearer " + spotify_token
                            }
                        )
    
        album_on_spotify =  'albums' in search_res.json() and len(search_res.json()['albums']['items']) != 0

        if not album_on_spotify:
            print("not on spotify: " + artist + " - " + project_name + " search term: " + search_term)

        if album_on_spotify:
            spotify_album = search_res.json()['albums']['items'][0]
            tracks_amt = spotify_album['total_tracks']
            release_year = int(spotify_album['release_date'][0:4])
            spotify_id = spotify_album['id']
            if spotify_album['images'] and len(spotify_album['images']) > 0:
                project_art = spotify_album['images'][-1]['url']
        
        



        
        album["spotify_id"] = spotify_id if album_on_spotify else ""
        album["youtube_id"] = vid_id
        album["project_name"] = project_name
        album["artist"] = artist
        album["project_type"] = project_type
        album["tracks"] = tracks_amt if album_on_spotify else -1
        album["project_art"] = project_art if album_on_spotify else ""
        album["year"] = release_year if album_on_spotify else -1
        album["rating"] = rating

        albums = albums.append(album,ignore_index=True)

        if VERBOSE:
            print("\033[1;30;43martist:\033[0m ", end='')
            print(artist, end=' ')
            print("\033[1;30;43mproject name:\033[0m ", end='')
            print(project_name, end=' ')
            print("\033[1;30;43mproject type:\033[0m ", end='')
            print(project_type, end=' ')


            print("\033[1;30;43mrelease year:\033[0m ", end='')
            print(release_year, end=' ')

            print("\033[1;30;43mrating:\033[0m ", end='')
            print(rating)


    

        if not album_on_spotify: continue

        #get tracks
        search_res = req.get(   'https://api.spotify.com/v1/albums/' + spotify_id + '/tracks',
                            params={
                                "limit": 50
                            },
                            headers={
                                'authorization': "Bearer " + spotify_token
                            }
                        )
        spotify_tracks = search_res.json()['items']
        

        
        for st in spotify_tracks:
            
            spotify_track_id = st['id']
            #get audio features of track
            search_res = req.get(   'https://api.spotify.com/v1/audio-features/' + spotify_track_id,
                            headers={
                                'authorization': "Bearer " + spotify_token
                            }
                        )
            has_audio_features = search_res != None and len(search_res.text) > 0 

            if has_audio_features:
                spotify_analysis = search_res.json()
            else:
                print("spotify audio features query failed: " + project_name)

            track = {}
            track["spotify_id"] = spotify_track_id
            track["album_id"] = spotify_id
            track["youtube_id"] = vid_id
            track["name"] = st['name']
            track["duration"] = st['duration_ms']
            track["explicit"] = st['explicit']
            track["preview"] = st['preview_url']
            track["key"] = spotify_analysis['key'] if has_audio_features and 'key' in spotify_analysis else -1
            track["mode"] = spotify_analysis['mode'] if has_audio_features and 'mode' in spotify_analysis else -1
            track["acousticness"] = spotify_analysis['acousticness'] if has_audio_features and 'acousticness' in spotify_analysis else -1
            track['danceability'] = spotify_analysis['danceability'] if has_audio_features and 'danceability' in spotify_analysis else -1
            track['energy'] = spotify_analysis['energy'] if has_audio_features and 'energy' in spotify_analysis else -1
            track['instrumentalness'] = spotify_analysis['instrumentalness'] if has_audio_features and 'instrumentalness' in spotify_analysis else -1
            track['liveness'] = spotify_analysis['liveness'] if has_audio_features and 'liveness' in spotify_analysis else -1
            track['loudness'] = spotify_analysis['loudness'] if has_audio_features and 'loudness' in spotify_analysis else -1
            track['speechiness'] = spotify_analysis['speechiness'] if has_audio_features and 'speechiness' in spotify_analysis else -1
            track['valence'] = spotify_analysis['valence'] if has_audio_features and 'valence' in spotify_analysis else -1
            track['tempo'] = spotify_analysis['tempo'] if has_audio_features and 'tempo' in spotify_analysis else -1
            

            tracks = tracks.append(track,ignore_index=True)
            
        
            bar.update()
            if VERBOSE:
                    
                print("\t" + track['name'], end=' ')
                t_min_str = str(track['duration'] // 60000)
                t_sec_str = "0" + str((track['duration'] // 1000) % 60) if (track['duration'] // 1000) % 60 < 10 else str((track['duration'] // 1000) % 60)
                print("(" + t_min_str + ":" + t_sec_str + ")", end=' ')
                
                track_key = ["C", "C#", "D", "D#", "E", "F", "F#", "G", "G#", "A", "A#", "B"][track['key']] if track['key'] != -1 else "unknown"
                print("\033[1;30;43mkey:\033[0m ",end='')
                print(track_key, end=' ')

                track_mode = "major" if track['mode'] == 1 else "minor"
                print("\033[1;30;43mmode:\033[0m ",end='')
                print(track_mode)
            
    bar.finish()
    #save to tracks.csv
    print(albums)
    print(tracks)
    tracks.to_csv('./data/tracks' + str(yr) + '.csv')
    albums.to_csv('./data/albums' + str(yr) + '.csv')
# Out:
# ChannelListResponse(kind='youtube#channelListResponse')
# collecting data for 2011
# no rating: Lil B- I'm Gay (I'm Happy) ALBUM REVIEW
# no rating: Wu-Tang Clan- Enter the Wu-Tang: 36 Chambers ALBUM REVIEW
# invalid title: Marvin Gaye- What's Going On
# no rating: Frank Zappa- Hot Rats ALBUM REVIEW
# no rating: Limp Bizkit- Gold Cobra ALBUM REVIEW
# no rating: Godspeed You! Black Emperor- Lift Yr. Skinny Fists Like Antennas to Heaven! ALBUM REVIEW
# no rating: Lady Gaga- Born This Way ALBUM REVIEW
# no rating: The Drums- Portamento ALBUM REVIEW
# no rating: 9th Wonder- The Wonder Years ALBUM REVIEW
# no rating: The Roots- Undun ALBUM REVIEW
# invalid title: Do messages matter?
# no rating: Deerhoof- Deerhoof vs Evil ALBUM REVIEW
# invalid title: YOU'RE NOT REVIEWING: Blink-182, The Game, Foster the People, and More
# invalid title: Boris- Heavy Rocks / Attention Please ALBUM REVIEWS
# invalid title: Top-10 Favorite Misfits Songs
# invalid title: 4 Reviews: The Weeknd / Gotye / Blood Orange / All Pigs Must Die
# invalid title: Y U NO REVIEW: NOV 2011
# invalid title: 10 White Stripes Songs I Love
# invalid title: 5 Debut Albums
# invalid title: Fav Dylan LPs?
# invalid title: Y U NO REVIEW: OCT 2011
# invalid title: Y U NO REVIEW: DEC' 11
# not on spotify: various artists - brand new wayo compilation search term: various artists brand new wayo compilation
# no rating: The Lonely Island- Turtleneck and Chain ALBUM REVIEW
# no rating: Neon Indian- Era Extraña ALBUM REVIEW
# invalid title: Master Musicians of Bukkake-Totem 3 ALBUM REVIEW
# invalid title: Master Musicians of Bukkake-Totem 3 ALBUM REVIEW
# no rating: Neon Indian- Era Extraña ALBUM REVIEW
# invalid title: 3 Reviews: Thurston Moore / SebastiAn / John Maus
# no rating: BADBADNOTGOOD- Rotten Decay TRACK REVIEW
# invalid title: 6 LPs: Ahead of Their Time
# no rating: Theophilus London- Timez Are Weird These Days ALBUM REVIEW (Dead End Hip Hop & The Needle Drop)
# invalid title: Music or Meme?
# invalid title: 4 Reviews: Surfer Blood, Nicolas Jaar, Morta Skuld, Animals As Leaders
# invalid title: 5 Reviews: Evidence, Azarath, Phonte, Youth Lagoon, Big Troubles
# invalid title: R.I.P. Gil Scott Heron
# invalid title: 5 Reviews: Black Lips, Ulver, Beirut, Krallice, and the Shivers
# invalid title: 4 Reviews: M83 / Kanye West & Jay-Z / The Drums / JEFF the Brotherhood
# invalid title: 3 Reviews: Cass McCombs / Childish Gambino / Africa Hitech
# invalid title: 3 Reviews: Big Sean / Curren$y / Sleeping Bag
# invalid title: 3 Reviews: Times New Viking / Natural Child / Deafheaven
# no rating: Mr. Muthafuckin' eXquire- Lost In Translation ALBUM REVIEW
# invalid title: 3 Reviews: Wilco / Dodkvlt / Valentin Stip
# invalid title: 3 Reviews: Man Man / Fucked Up / Matthewdavid
# invalid title: Favorite EPs of 2011
# invalid title: Negative opinions?
# invalid title: Future Islands- On the Water ALBUM REIVEW
# invalid title: 15 Bands I'll See @ SXSW
# invalid title: Do you support music?
# invalid title: Music evolves.
# invalid title: Does Music Grow?
# invalid title: Biggest Let-Downs of 2011 (so far)
# invalid title: Image affects you.
# invalid title: Free music.
# invalid title: Favorite Music Videos of 2011
# invalid title: Favorite Singles of 2011
# invalid title: Originality?
# invalid title: Favorite Albums of 2011 (so far)
# invalid title: Sex music?
# invalid title: SXSW '11 Vlog 1
# invalid title: SXSW '11 Vlog 2
# invalid title: SXSW '11 Vlog 4
# invalid title: 16 Most Anticipated 2011 Albums
# invalid title: SXSW '11 Vlog 3
#                  spotify_id   youtube_id  \
# 0    1bkN9nIkkCnXeG4yitVS1J  1nYHyZgD5zM
# 1    3FgLMfp5o2h2rAny7S6h57  RUNnXRjmGoQ
# 2    5dbCm8qaCdWnNdVyi3urUO  IT2XYrIJHSA
# 3    32KdoFFhgjCLdU0DWL71tx  EGFCKb5PfDA
# 4    2P2Xwvh2xWXIZ1OWY9S9o5  HLMuUZhHZqE
# ..                      ...          ...
# 199  2Rx7aDr2gtQVXmNOdaZZPG  rcz78ic8CGw
# 200  0kNc7P4kmG5ZQbCvI44R9B  7hpw4H18k3M
# 201  3AYIOYVoTIEM89wFJ7y6eI  zNbdh-JzTDY
# 202  2nBo5nFoszkjuY0bxv1y0A  UWcxXnus0zY
# 203  53FEYOXnplxBWoQMmWn82U  j48qLgyg7PE
#
#                                       project_name  \
# 0                                       section.80
# 1                                             lulu
# 2                                           goblin
# 3                                             camp
# 4                                 watch the throne
# ..                                             ...
# 199                                  angels exodus
# 200  coin coin chapter one: gens de couleur libres
# 201                                    "night air"
# 202                "the rose with the broken neck"
# 203                             limit to your love
#
#                            artist project_type  tracks  \
# 0                  kendrick lamar        album    15.0
# 1          lou reed and metallica        album    10.0
# 2              tyler, the creator        album    18.0
# 3                childish gambino        album    13.0
# 4              kanye west & jay-z        album    16.0
# ..                            ...          ...     ...
# 199                         lil b        album    12.0
# 200                matana roberts        album     8.0
# 201                    jamie woon        track     4.0
# 202  danger mouse & daniele luppi        track    15.0
# 203                   james blake        track    10.0
#
#                                            project_art    year  rating
# 0    https://i.scdn.co/image/ab67616d00004851eddb26...  2011.0     8.0
# 1    https://i.scdn.co/image/ab67616d00004851bf3f45...  2011.0     6.0
# 2    https://i.scdn.co/image/ab67616d0000485128ae9a...  2011.0     4.0
# 3    https://i.scdn.co/image/ab67616d000048516f134f...  2011.0     2.0
# 4    https://i.scdn.co/image/ab67616d000048514a7677...  2011.0     5.0
# ..                                                 ...     ...     ...
# 199  https://i.scdn.co/image/ab67616d0000485175583d...  2011.0     3.0
# 200  https://i.scdn.co/image/ab67616d00004851945e39...  2011.0     8.0
# 201  https://i.scdn.co/image/ab67616d00004851327e92...  2010.0     5.0
# 202  https://i.scdn.co/image/ab67616d00004851574860...  2011.0     3.0
# 203  https://i.scdn.co/image/ab67616d00004851d134db...  2013.0     8.0
#
# [204 rows x 9 columns]
#                   spotify_id                album_id   youtube_id  \
# 0     1gXH8hT9dxsBqbRy7h2iC8  1bkN9nIkkCnXeG4yitVS1J  1nYHyZgD5zM
# 1     6cfVDaIdvDtYH91RqC6Wox  1bkN9nIkkCnXeG4yitVS1J  1nYHyZgD5zM
# 2     2Fw5S2gaOSZzdN5dFoC2dj  1bkN9nIkkCnXeG4yitVS1J  1nYHyZgD5zM
# 3     3L2YOO6dDiB91M1AbQ0CCR  1bkN9nIkkCnXeG4yitVS1J  1nYHyZgD5zM
# 4     22gXA7HlEd0z13zdc3hju7  1bkN9nIkkCnXeG4yitVS1J  1nYHyZgD5zM
# ...                      ...                     ...          ...
# 2266  0bER7hZcp3jwwJmaGAvksS  53FEYOXnplxBWoQMmWn82U  j48qLgyg7PE
# 2267  0BQV07dSwLltMlLDo47ckp  53FEYOXnplxBWoQMmWn82U  j48qLgyg7PE
# 2268  0Zaq26GPf2emAuRPsMXKGC  53FEYOXnplxBWoQMmWn82U  j48qLgyg7PE
# 2269  4UZeOqDHc9KluSril899KL  53FEYOXnplxBWoQMmWn82U  j48qLgyg7PE
# 2270  0BCAtiPr3fBKqfEWaUmCUh  53FEYOXnplxBWoQMmWn82U  j48qLgyg7PE
#
#                                             name  duration  explicit  \
# 0                            F*ck Your Ethnicity  224671.0       1.0
# 1                                        Hol' Up  173158.0       1.0
# 2                                        A.D.H.D  215509.0       1.0
# 3     No Make-Up (Her Vice) (feat. Colin Munroe)  235921.0       1.0
# 4                       Tammy's Song (Her Evils)  161670.0       1.0
# ...                                          ...       ...       ...
# 2266                                         DLM  145920.0       0.0
# 2267                                Digital Lion  287013.0       0.0
# 2268                                      Voyeur  257746.0       0.0
# 2269                                 To The Last  259693.0       0.0
# 2270                         Our Love Comes Back  219026.0       0.0
#
#                                                 preview   key  mode  \
# 0     https://p.scdn.co/mp3-preview/14975a6c4cfdf032...   0.0   1.0
# 1     https://p.scdn.co/mp3-preview/044db205a049cb99...   5.0   1.0
# 2     https://p.scdn.co/mp3-preview/74a5d932b70d9512...   9.0   1.0
# 3     https://p.scdn.co/mp3-preview/d3b6b6dbddbd877a...   5.0   0.0
# 4     https://p.scdn.co/mp3-preview/7c847d8b9643792a...   9.0   0.0
# ...                                                 ...   ...   ...
# 2266                                               None   2.0   1.0
# 2267                                               None  11.0   0.0
# 2268                                               None   7.0   0.0
# 2269                                               None  11.0   0.0
# 2270                                               None   9.0   0.0
#
#       acousticness  danceability  energy  instrumentalness  liveness  \
# 0           0.3920         0.601   0.883          0.000019    0.3970
# 1           0.7810         0.607   0.869          0.000000    0.1370
# 2           0.3300         0.609   0.799          0.000000    0.1080
# 3           0.5410         0.535   0.696          0.005210    0.6300
# 4           0.9240         0.477   0.835          0.000508    0.1290
# ...            ...           ...     ...               ...       ...
# 2266        0.9690         0.401   0.170          0.007110    0.0992
# 2267        0.1820         0.498   0.654          0.696000    0.1170
# 2268        0.0481         0.519   0.702          0.312000    0.0855
# 2269        0.7160         0.536   0.599          0.009030    0.1400
# 2270        0.9710         0.328   0.193          0.441000    0.1410
#
#       loudness  speechiness  valence    tempo
# 0       -6.944       0.3280    0.520  150.967
# 1       -5.271       0.3450    0.577  155.983
# 2       -6.883       0.2400    0.582  157.740
# 3       -7.181       0.0901    0.213   91.002
# 4       -5.942       0.4380    0.520   97.317
# ...        ...          ...      ...      ...
# 2266   -15.077       0.0422    0.082  132.923
# 2267    -9.859       0.0370    0.254  134.940
# 2268    -6.761       0.0342    0.317  124.931
# 2269   -11.785       0.0612    0.116  140.048
# 2270   -18.655       0.0357    0.126  137.493
#
# [2271 rows x 18 columns]
# collecting data for 2012
# c:\Python38\lib\site-packages\dataclasses_json\core.py:171: RuntimeWarning: `NoneType` object value of non-optional type relevantTopicIds detected when decoding VideoTopicDetails.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# no rating: Madvillain- Madvillainy ALBUM REVIEW
# no rating: Neutral Milk Hotel - In the Aeroplane Over the Sea ALBUM REVIEW
# no rating: Actress- R.I.P. ALBUM REVIEW
# no rating: Gorillaz- "DoYaThing" TRACK REVIEW
# invalid title: Earl Sweatshirt, Ghost, A$AP Rocky, Starkey T.I., Wiz Khalifa, Yo La Tengo, and more w/the Quickness
# invalid title: Y U NO REVIEW: JUNE '12
# no rating: Various Artists- Cruel Summer COMPILATION REVIEW
# invalid title: Y U NO REVIEW: JUNE '12
# invalid title: Y U NO REVIEW: August '12
# no rating: Mac Miller- Macadelic ALBUM REVIEW
# no rating: Lil B- California Boy RARE TRACK REVIEW
# invalid title: Top-10 Rage Against the Machine Songs
# no rating: Muse- "The 2nd Law: Unsustainable" TRACK REVIEW
# invalid title: Big Boi- Vicious Lies and Dangerous Rumors
# invalid title: Y U NO REVIEW: MARCH '12
# invalid title: Do we respect the past? (Tupac Hologram Reaction)
# no rating: Animal Collective- Today's Supernatural TRACK REVIEW
# invalid title: Ty Segall Band- Slaughterhouse / Ty Segall & White Fence- Hair ALBUM REVIEWS
# no rating: Death Grips- "@DEATHGRIPZ" TRACK REVIEW
# no rating: Crystal Castles- Plague TRACK REVIEW
# no rating: Lapalux- When You're Gone EP REVIEW
# invalid title: My 10 Favorite Velvet Underground Songs
# not on spotify: 3:33 - in the middle of infinity search term: 3:33 in the middle of infinity
# no rating: Atoms For Peace- "Default" TRACK REVIEW
# no rating: Suns- The Engine Room ALBUM REVIEW
# invalid title: What is a 10?
# invalid title: Animal Collective- "Honeycomb" and "Gotham" TRACK REVIEWS
# invalid title: My Vinyl Collection: Part 6
# invalid title: My headphones!
# invalid title: YouTube Music Reviewers
# invalid title: My favorite band broke up!
# invalid title: My Vinyl Collection: Part 1
# invalid title: NO GUILTY PLEASURES!
# no rating: Milo- "Prince Abakaliki of Nigeria needs your help" TRACK REVIEW
# no rating: The Shins- "Simple Song" TRACK REVIEW
# invalid title: Zammuto- Self-Titled ALBUM REVEW
# no rating: Sufjan Stevens- Silver & Gold ALBUM REVIEW
# no rating: Ceremony- "Hysteria" TRACK REVIEW
# invalid title: Assholes In Music?
# invalid title: Does audio quality matter anymore??
# invalid title: _____ is dead!
# invalid title: 6 Audio Reviews: Laurel Halo, Edward Sharpe, Havok, and More
# invalid title: Short Audio Reviews: Reks, Santigold, Logic, Dot hacker
# invalid title: Short Audio Reviews: King Tuff, Daughn Gibson, Slugabed, Public Image Ltd., and Melvins Lite
# invalid title: Short Audio Reviews: Orbital, Lord Mantis, Here We Go Magic, Author & Punisher
# invalid title: Real ____?
# invalid title: The Flaming Lips- The Flaming Lips and Heady Fwends
# invalid title: Top-50 Singles of 2012
# invalid title: My favorite band reunited!
# invalid title: Top-15 EPs of 2012
# invalid title: From "T.R.O.Y." to "Around My Way"
# invalid title: The Radio???
# invalid title: Great Albums: September '12
# invalid title: Great Albums: November '12
# invalid title: Too many musicians?
# invalid title: Great Albums: February '12
# invalid title: Anticipated Albums: 2012 Edition
# invalid title: MUSIC IS EVERYWHERE!
# invalid title: Great Albums: March '12
# invalid title: EPIC YUNOREVIEW OF SADNESS!
# invalid title: Great Albums: July '12
# invalid title: Great Albums: October '12
# invalid title: Great Albums: April '12
# invalid title: Top-25 Music Videos of 2012
# invalid title: Music Movies
# invalid title: Top-50 Albums of 2012
# invalid title: My Vinyl Collection: Part 2
# invalid title: Great Albums: August 2012
# invalid title: Music on a cube?
# invalid title: Great Albums: May '12
# invalid title: Explore!!!!
# invalid title: Universal steals music?
# invalid title: Getting Your Music Out There
# invalid title: Bands I'll See At SXSW
# invalid title: Hipster!!!
# invalid title: My Vinyl Collection: Part 8
# invalid title: My Vinyl Collection: Part 3
# invalid title: CONTEXT IMPACTS EVERYTHING!
# invalid title: My Vinyl Collection: Part 12
# invalid title: My Vinyl Collection: Part 5
# invalid title: 10 Great Record Store Day Releases
# invalid title: Favorite Albums of 2012...SO FAR!
# invalid title: My Vinyl Collection: Part 9
# invalid title: My Vinyl Collection: Part 16
# invalid title: My Vinyl Collection: Part 13
# invalid title: My Vinyl Collection: Part 10
# invalid title: Great Albums: June '12
# invalid title: My Vinyl Collection: Part 11
# invalid title: My Vinyl Collection: Part 15
# invalid title: My Vinyl Collection: Part 14
# invalid title: Cal's Favorite Music of 2012 (So Far)
# invalid title: My Vinyl Collection: Part 7
# invalid title: Taste = Character?
# invalid title: Anthony Speaks at Wesleyan: Q&A Pt. 2
# invalid title: ???
# invalid title: WORKOUT MIX 2012!!!
# invalid title: My Setup / Audio Equipment Talk
# invalid title: Streaming music?
# invalid title: I'm moving!
# invalid title: 20 Favorite Beastie Boys Songs
# invalid title: My Vinyl Collection: Part 4
# invalid title: Will we stop SOPA and PIPA?
# invalid title: Pussy Riot's Closing Statements
# invalid title: SXSW 2012 Vlog 4
# invalid title: SXSW 2012 Vlog 2
# invalid title: SXSW 2012 Vlog 1
# invalid title: Anthony Speaks at Wesleyan: Lecture Pt. 2 + Q&A Pt. 1
# invalid title: Anthony Speaks at Wesleyan: Lecture Pt. 1
#                  spotify_id   youtube_id  \
# 0    1PQDjdBpHPikAodJqjzm6a  mK54P7VeM1g
# 1    3DGQ1iZ9XKUQxAUWjfC34w  VUUxtEQLAiQ
# 2    6k3vC8nep1BfqAIJ81L6OL  _TZBdHjgMxI
# 3    1lJn3Ku809KZKTS3411iTT  pRL_6Lf9Xrg
# 4    4VDX4YuDzvaRPfHaZ4FrFV  aUClt-ivlH0
# ..                      ...          ...
# 213  7usMqTegkIEWcERDDK5i9L  NImDLA14kHs
# 214  0eEbkruD1cv8OfcUd3JaQJ  4EzQRbeLeXk
# 215  05bvtbRjfvIXzCS1PpEaji  RNOWaELu2TM
# 216  2rNvaIp7nBgCyFT7xpAyZ6  J6xkvLGQbAU
# 217  1WSHvpxWbV3DbE6h36jtmu  Sx7w_3vZ3F4
#
#                                  project_name  \
# 0                             the money store
# 1                     good kid, m.a.a.d. city
# 2                             an awesome wave
# 3                              advaitic songs
# 4                                floral green
# ..                                        ...
# 213                take the kids off broadway
# 214         amongst these splintered minds...
# 215                                ocean roar
# 216  see the world given to a one love entity
# 217                                dross glop
#
#                                  artist project_type  tracks  \
# 0                           death grips        album    13.0
# 1                        kendrick lamar        album    17.0
# 2                                 alt-j        album    14.0
# 3                                    om        album     5.0
# 4                           title fight        album    11.0
# ..                                  ...          ...     ...
# 213                             foxygen           ep     7.0
# 214  the act of estimating as worthless        album    12.0
# 215                         mount eerie        album     8.0
# 216                      guardian alien        album     1.0
# 217                             battles        album    12.0
#
#                                            project_art    year  rating
# 0    https://i.scdn.co/image/ab67616d00004851b4f845...  2012.0     1.0
# 1    https://i.scdn.co/image/ab67616d00004851d58e53...  2012.0     9.0
# 2    https://i.scdn.co/image/ab67616d00004851df8cad...  2012.0     8.0
# 3    https://i.scdn.co/image/ab67616d00004851611acf...  2012.0     5.0
# 4    https://i.scdn.co/image/ab67616d000048513c1508...  2012.0     7.0
# ..                                                 ...     ...     ...
# 213  https://i.scdn.co/image/ab67616d00004851a4fc1b...  2012.0     8.0
# 214  https://i.scdn.co/image/ab67616d0000485171ba9e...  2012.0     7.0
# 215  https://i.scdn.co/image/ab67616d0000485126fdf8...  2012.0     5.0
# 216  https://i.scdn.co/image/ab67616d0000485113f042...  2012.0     6.0
# 217  https://i.scdn.co/image/ab67616d00004851a78d75...  2012.0     6.0
#
# [218 rows x 9 columns]
#                   spotify_id                album_id   youtube_id  \
# 0     781V2Y5LPtcpgONEOadadE  1PQDjdBpHPikAodJqjzm6a  mK54P7VeM1g
# 1     5lq6hpsabgw22xRYPHVV5c  1PQDjdBpHPikAodJqjzm6a  mK54P7VeM1g
# 2     4Q3ikbp3CWt0Gp4iYDt4lV  1PQDjdBpHPikAodJqjzm6a  mK54P7VeM1g
# 3     4mRuyccI90TUWJKP7qdYvX  1PQDjdBpHPikAodJqjzm6a  mK54P7VeM1g
# 4     5PXyH5bb5fbVfO8LjByhBb  1PQDjdBpHPikAodJqjzm6a  mK54P7VeM1g
# ...                      ...                     ...          ...
# 2565  1hJ6AdBH8SaJe7vuU1BYm1  1WSHvpxWbV3DbE6h36jtmu  Sx7w_3vZ3F4
# 2566  3xPUPf0wyPw6FOK1LWZbu9  1WSHvpxWbV3DbE6h36jtmu  Sx7w_3vZ3F4
# 2567  1BVAmHJTpSRb5fi9mIsTCa  1WSHvpxWbV3DbE6h36jtmu  Sx7w_3vZ3F4
# 2568  06vLzcZ4WbIMK7SH92NMxU  1WSHvpxWbV3DbE6h36jtmu  Sx7w_3vZ3F4
# 2569  6slG54Q5lXvAmF3xKawhRM  1WSHvpxWbV3DbE6h36jtmu  Sx7w_3vZ3F4
#
#                                                    name  duration  explicit  \
# 0                                               Get Got  171866.0       1.0
# 1                                   The Fever (Aye Aye)  186973.0       1.0
# 2                                             Lost Boys  186320.0       1.0
# 3                                             Blackjack  142000.0       1.0
# 4                                          Hustle Bones  192360.0       1.0
# ...                                                 ...       ...       ...
# 2565                     Dominican Fade (Qluster Remix)  223306.0       0.0
# 2566             Ice Cream (BDG #Gang Gang Dance Remix)  246066.0       0.0
# 2567                 Rolls Bayce (Hudson Mohawke Remix)  258893.0       0.0
# 2568  My Machines (Patrick Mahoney & Dennis McNany R...  551773.0       0.0
# 2569                                Sundome (EYE Remix)  342000.0       0.0
#
#                                                 preview   key  mode  \
# 0     https://p.scdn.co/mp3-preview/3b821fca0086522d...   7.0   1.0
# 1     https://p.scdn.co/mp3-preview/3d14cbd25e7ae2f0...  10.0   0.0
# 2     https://p.scdn.co/mp3-preview/e2f8eeb55d8e8bd4...   2.0   1.0
# 3     https://p.scdn.co/mp3-preview/f47d49d8b3b1198b...   4.0   0.0
# 4     https://p.scdn.co/mp3-preview/f183179bc29311a7...   4.0   0.0
# ...                                                 ...   ...   ...
# 2565  https://p.scdn.co/mp3-preview/839df1aa45f1dc51...  11.0   0.0
# 2566  https://p.scdn.co/mp3-preview/569ab738d324ed4a...   9.0   0.0
# 2567  https://p.scdn.co/mp3-preview/6ad3cb10fa2804f0...   0.0   1.0
# 2568  https://p.scdn.co/mp3-preview/fce3afb347cef2f2...   9.0   1.0
# 2569  https://p.scdn.co/mp3-preview/ebf879467f99e28b...   6.0   0.0
#
#       acousticness  danceability  energy  instrumentalness  liveness  \
# 0         0.006280         0.570   0.993          0.007960    0.0876
# 1         0.159000         0.432   0.940          0.000000    0.1540
# 2         0.003000         0.464   0.949          0.000113    0.0808
# 3         0.259000         0.532   0.855          0.000000    0.1120
# 4         0.104000         0.600   0.982          0.000000    0.3430
# ...            ...           ...     ...               ...       ...
# 2565      0.223000         0.558   0.532          0.944000    0.0865
# 2566      0.028700         0.859   0.735          0.010700    0.3490
# 2567      0.004740         0.524   0.728          0.275000    0.0681
# 2568      0.000479         0.691   0.459          0.330000    0.0872
# 2569      0.000189         0.548   0.841          0.507000    0.3500
#
#       loudness  speechiness  valence    tempo
# 0       -3.757       0.3370    0.405   87.000
# 1       -4.099       0.3740    0.225   80.084
# 2       -2.454       0.3360    0.374   77.121
# 3       -3.014       0.3010    0.534  136.902
# 4       -2.996       0.2010    0.277  110.015
# ...        ...          ...      ...      ...
# 2565   -13.002       0.0438    0.249  177.012
# 2566    -5.045       0.0942    0.773  106.259
# 2567    -7.954       0.0334    0.222  172.943
# 2568    -6.201       0.0405    0.362  125.020
# 2569    -6.018       0.0876    0.242  129.962
#
# [2570 rows x 18 columns]
# collecting data for 2013
# c:\Python38\lib\site-packages\dataclasses_json\core.py:171: RuntimeWarning: `NoneType` object value of non-optional type relevantTopicIds detected when decoding VideoTopicDetails.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# no rating: Eminem - "Rap God" TRACK REVIEW ("Berzerk," too!)
# no rating: My Bloody Valentine- Loveless ALBUM REVIEW
# no rating: Miles Davis- Bitches Brew ALBUM REVIEW
# no rating: King Crimson- In the Court of the Crimson King ALBUM REVIEW
# no rating: Johnny Cash - At Folsom Prison ALBUM REVIEW
# no rating: The Velvet Underground & Nico - Self-Titled ALBUM REVIEW
# no rating: Mazzy Star - Seasons Of Your Day ALBUM REVIEW (QUICK)
# no rating: Arca - &&&&& MIX REVIEW
# no rating: Yung Lean - Unknown Death 2002 MIXTAPE REVIEW
# no rating: Lorde - Pure Heroine ALBUM REVIEW (QUICK)
# invalid title: Farewell, Lou Reed. (Re:flection #9)
# not on spotify: mr. muthafuckin' exquire - kismet search term: mr. muthafuckin' exquire kismet
# invalid title: The Strokes, Matmos, Biffy Clyro, Joe Budden, Mister Lies, Sannhet, Inc., and more w/the Quickness
# no rating: Dead Kennedys- Plastic Surgery Disasters ALBUM REVIEW
# no rating: Black Sabbath - 13 ALBUM REVIEW
# no rating: Big Sean - "Control" ft. Kendrick Lamar, Jay Electronica TRACK REVIEW
# no rating: CHVRCHES - The Bones of What You Believe ALBUM REVIEW (QUICK)
# invalid title: Accessible vs. Experimental vs. Inacessible vs. Mainstream vs. Underground vs. Simple vs. Complex
# no rating: Sampha - DUAL EP REVIEW
# no rating: Mount Kimbie - Cold Spring Fault Less Youth ALBUM REVIEW (QUICK)
# no rating: Kyary Pamyu Pamyu - Nandacollection ALBUM REVIEW (きゃりーぱみゅぱみゅ - なんだこれくしょん)
# no rating: Glasser - Interiors ALBUM REVIEW
# invalid title: CX KiDTRONiK: KRAK ATTACK 2: THE BALLAD OF ELLI SKIFF ALBUM REVIEW
# no rating: All Pigs Must Die - Nothing Violates This Nature ALBUM REVIEW (QUICK)
# no rating: Death Grips - "Birds" TRACK REVIEW
# invalid title: What's generic?
# not on spotify: soupcans - parasite brain search term: soupcans parasite brain
# no rating: Tyler, The Creator - "Domo 23" TRACK REVIEW
# invalid title: Logic - Young Sinatra: Welcome To Forever ALBUM REVEW (QUICK)
# invalid title: Depeche Mode, CHVRCHES, Tera Melos, Wire, Black Angels, TNGHT, Holograms, and more w/the Quickness
# no rating: Jarren Benton - My Grandmother's Basement ALBUM REVIEW (Quick)
# not on spotify: denzel curry - nostalgic 64 search term: denzel curry nostalgic 64
# no rating: Sigur Rós - Kveikur ALBUM REVIEW (QUICK)
# no rating: Pharmakon - Abandon ALBUM REVIEW (QUICK)
# no rating: Baauer - "Harlem Shake" TRACK REVIEW
# no rating: Arcade Fire - "Reflektor" TRACK REVIEW
# invalid title: Earl, Sigur Ros, Kavinsky, Warm Soda, Blue Willa, Savages, and Bilal w/the Quickness
# no rating: Power Trip - Manifest Decimation ALBUM REVIEW (QUICK)
# no rating: Primal Scream - More Light ALBUM REVIEW (QUICK)
# no rating: The Strokes - "One Way Trigger" TRACK REVIEW
# invalid title: Vampire Weekend - "Step" / "Diane Young" TRACK REVIEWS
# no rating: Milo - Cavalcade MIXTAPE REVIEW (QUICK...NOT REALLY)
# no rating: Fuzz - Self-Titled ALBUM REVIEW
# no rating: Jagwar Ma - Howlin ALBUM REVIEW (QUICK)
# no rating: Ghostpoet - Some Say I So I Say Light ALBUM REVIEW (QUICK)
# no rating: The Dismemberment Plan - Uncanny Valley ALBUM REVIEW (QUICK)
# invalid title: Ratings / Scores: Why?
# no rating: Action Bronson - Saaab Stories EP REVIEW (prod. Harry Fraud)
# no rating: Havok - Unnatural Selection ALBUM REVIEW
# no rating: Daftside - Random Access Memories Memories REMIX ALBUM REVIEW
# no rating: Hopsin - "Ill Mind of Hopsin 6" TRACK REVIEW
# invalid title: Miley uses sex, because sex sells music. (And we've all bought it.) (Re:flection #1)
# invalid title: James Blake, Pusha T, Grave Babies, Jim James, Darkstar, Lee Bannon, and more w/the Quickness
# no rating: Haim - Days Are Gone ALBUM REVIEW (WELL, A LINK TO IT...)
# invalid title: Bad Religion, New Order, Widowspeak, Just Blaze, Gold Panda, and Casey Veggies w/the Quickness
# invalid title: Daft Punk, MGMT, Savages, Marnie Stern, Laura Mvula, Disclosure, and more w/the Quickness
# invalid title: Shlohmo, Justin Timberlake, Factory Floor, Fidlar, Chris Owens, and more w/the Quickness
# invalid title: Adam Green & Binki Shapiro - Self-TItled
# invalid title: I Saw Ghostface Killah!
# invalid title: Flaming Lips, Voivod, Nails, The Knife, Bleeding Rainbow, Bonobo, and more w/the Quickness
# invalid title: Vinyl Update: 01-27-13
# invalid title: David Bowie, Iceage, Atoms For Peace, Anamanaguchi, Skrillex, and more w/the Quickness
# invalid title: Long Haul vs. Burning Out (Re:flection #5)
# invalid title: I saw Swans!
# invalid title: Vinyl Update: 02-25-13
# invalid title: Great Albums: February '13
# invalid title: Does location matter less?
# invalid title: Are genres good?
# invalid title: What's in a comeback?
# invalid title: Great Albums: June and July '13
# invalid title: Great Albums: September 2013
# invalid title: I saw King Krule (and Ratking)!
# invalid title: Favorite Music of 2013 (So Far...)
# invalid title: I Saw Shabazz Palaces!
# invalid title: Great Albums: May '13
# invalid title: Artists I'll See @ SXSW: 2013 Edition
# invalid title: Great Albums: April '13
# invalid title: Great Albums: August '13
# invalid title: Great Albums: March '13
# invalid title: NEW TRACK: Ratking - "100"
# invalid title: Hype: Good or Bad?
# invalid title: Image can drive great music. Pretenders will be forgotten! (Re:flection #3)
# invalid title: Overrated / Underrated: 2013 (So far...)
# invalid title: Honorable Mentions: 2013
# invalid title: Autre Ne Veut, Wayne Shorter, Black Pus, Pete Swanson, Bad History Month, and more w/the Quickness
# invalid title: LIVE w/The RIOB: "Reflektor," David Libe Hart, DIIV Heroin, Man Man Review
# invalid title: Great Albums: October 2013
# invalid title: Top-15 EPs of 2013
# invalid title: SXSW 2013 Clip Show!
# invalid title: Anticipated Albums: 2013 Edition
# invalid title: Great Albums: November / December '13
# invalid title: Great Albums: Jan '13
# invalid title: Top-50 Albums of 2013
# invalid title: What's musical taste?
# invalid title: Record Store Day Picks: 2013
# invalid title: I Saw Jeff Mangum!
# invalid title: NEW TRACK: Artificial Brain - "Absorbing Black Ignition"
# invalid title: NEW TRACK: St. Vincent - "Birth In Reverse"
# invalid title: Why harass musicians? (Re:flection #7)
# invalid title: Vinyl Update: 12-14-13
# invalid title: Vinyl Update: 04-07-13
# invalid title: Top-50 Singles of 2013
# invalid title: Vinyl Update: 06-03-13
# invalid title: Top-25 Music Videos of 2013
# invalid title: Interview w/Milo
# invalid title: Should you print your album?
# invalid title: I Saw Anamanaguchi!
# invalid title: NEW TRACK: MANKIND - "Blood, Sugar"
# invalid title: NEW TRACK: MGMT - "Your Life Is A Lie"
# invalid title: WORKING OUT MIX: 2013 #MAGIC @THENEEDLEDROP
# invalid title: NEW TRACK: Earl - "Hive"
# invalid title: 222,222 Subscriber Special!!!
# invalid title: NEW TRACK: Melt Yourself Down - "Fix My Life"
# invalid title: Cal Chuchesta / Weird Vibes
# invalid title: NEW TRACK: Mount Kimbie - "You Took Your Time" ft. King Krule
# invalid title: Mini Interview With BADBADNOTGOOD
#                  spotify_id   youtube_id  \
# 0    7D2NdGvBHIavgLhmcwhluK  Vns-81egipQ
# 1    6DN7GcZF1HywzrkGN6Eeqk  K2uBdDrUIqU
# 2    4m2880jivSbbyEGAKfITCa  tTUBoFVi-HY
# 3    40QTqOBBxCEIQlLNdSjFQB  aspbCJ68zqY
# 4    4EK8gtQfdVsmDTji7gBFlz  Od7fLNhEecM
# ..                      ...          ...
# 195  6BtVMqZ9Ra2aTGqbdZ61aW  XiSU9xDyJc0
# 196  5S4tasGYxpQuSEWLYvgyQp  C6ptrREuJGA
# 197  3jtvAZXAzNnEMrAsRAr1lJ  VysUDwL62z4
# 198  5mBOGECzXM9rkVvECALl9B  MYJHHxjlwOQ
# 199  1bvCVYPVl445mO690M2dOr  hwEA9vhpQDA
#
#                                       project_name              artist  \
# 0                                           yeezus          kanye west
# 1                        the marshall mathers lp 2              eminem
# 2                           random access memories           daft punk
# 3                                             wolf  tyler, the creator
# 4                                       melophobia   cage the elephant
# ..                                             ...                 ...
# 195                                         honeys        pissed jeans
# 196                                   miracle mile              strfkr
# 197                waiting for something to happen      veronica falls
# 198  new history warfare vol. 3: to see more light       colin stetson
# 199                            night time, my time        sky ferreira
#
#     project_type  tracks                                        project_art  \
# 0          album    10.0  https://i.scdn.co/image/ab67616d000048511dacfb...
# 1          album    21.0  https://i.scdn.co/image/ab67616d00004851cb66bc...
# 2          album    13.0  https://i.scdn.co/image/ab67616d000048511d97ca...
# 3          album    18.0  https://i.scdn.co/image/ab67616d000048516be680...
# 4          album    10.0  https://i.scdn.co/image/ab67616d00004851fb1cb9...
# ..           ...     ...                                                ...
# 195        album    12.0  https://i.scdn.co/image/ab67616d00004851b57d5e...
# 196        album    15.0  https://i.scdn.co/image/ab67616d00004851cb916d...
# 197        album    13.0  https://i.scdn.co/image/ab67616d00004851a6fe30...
# 198        album    11.0  https://i.scdn.co/image/ab67616d00004851988fd4...
# 199        album    12.0  https://i.scdn.co/image/ab67616d0000485106b4e0...
#
#        year  rating
# 0    2013.0     5.0
# 1    2013.0     7.0
# 2    2013.0     8.0
# 3    2013.0     6.0
# 4    2013.0     8.0
# ..      ...     ...
# 195  2013.0     7.0
# 196  2013.0     3.0
# 197  2013.0     6.0
# 198  2013.0     7.0
# 199  2013.0     4.0
#
# [200 rows x 9 columns]
#                   spotify_id                album_id   youtube_id  \
# 0     1gqkRc9WtOpnGIqxf2Hvzr  7D2NdGvBHIavgLhmcwhluK  Vns-81egipQ
# 1     722tgOgdIbNe3BEyLnejw4  7D2NdGvBHIavgLhmcwhluK  Vns-81egipQ
# 2     0HMCdlOPJkAGlB0MlSWIcO  7D2NdGvBHIavgLhmcwhluK  Vns-81egipQ
# 3     4cAgkb0ifwn0FSHGXnr4F6  7D2NdGvBHIavgLhmcwhluK  Vns-81egipQ
# 4     5nIu0VwPOsjkF61zfevLKh  7D2NdGvBHIavgLhmcwhluK  Vns-81egipQ
# ...                      ...                     ...          ...
# 2350  3k5SxXdbEzyHfE7wiJl0ya  1bvCVYPVl445mO690M2dOr  hwEA9vhpQDA
# 2351  07w29sqWmeBlffYaFnSSd0  1bvCVYPVl445mO690M2dOr  hwEA9vhpQDA
# 2352  5HEeBCUDho3uQVNu98CvsS  1bvCVYPVl445mO690M2dOr  hwEA9vhpQDA
# 2353  1EuOJLjHYZCEPcGJqAC3wZ  1bvCVYPVl445mO690M2dOr  hwEA9vhpQDA
# 2354  7d3BrpkSkKJpMdOuSnHxtH  1bvCVYPVl445mO690M2dOr  hwEA9vhpQDA
#
#                      name  duration  explicit preview  key  mode  \
# 0                On Sight  156480.0       1.0    None  9.0   0.0
# 1          Black Skinhead  188013.0       1.0    None  1.0   1.0
# 2              I Am A God  231506.0       1.0    None  4.0   0.0
# 3              New Slaves  256093.0       1.0    None  1.0   1.0
# 4          Hold My Liquor  326946.0       1.0    None  8.0   1.0
# ...                   ...       ...       ...     ...  ...   ...
# 2350    Heavy Metal Heart  255213.0       0.0    None  5.0   1.0
# 2351             Kristine  159306.0       0.0    None  9.0   0.0
# 2352               I Will  198106.0       0.0    None  7.0   1.0
# 2353       Love In Stereo  197333.0       0.0    None  2.0   1.0
# 2354  Night Time, My Time  230880.0       0.0    None  7.0   0.0
#
#       acousticness  danceability  energy  instrumentalness  liveness  \
# 0         0.487000         0.605   0.469          0.000000    0.2800
# 1         0.001100         0.766   0.809          0.000000    0.1680
# 2         0.036700         0.510   0.532          0.000794    0.1650
# 3         0.165000         0.506   0.590          0.000011    0.0960
# 4         0.019400         0.497   0.322          0.000008    0.1150
# ...            ...           ...     ...               ...       ...
# 2350      0.000785         0.257   0.857          0.000001    0.0864
# 2351      0.000309         0.472   0.881          0.000000    0.1410
# 2352      0.000002         0.329   0.909          0.381000    0.3520
# 2353      0.021800         0.736   0.717          0.004960    0.2870
# 2354      0.268000         0.425   0.645          0.689000    0.6520
#
#       loudness  speechiness  valence    tempo
# 0       -3.182       0.3270    0.515  101.601
# 1       -6.123       0.2790    0.325  130.127
# 2       -7.405       0.0715    0.305  111.885
# 3       -4.322       0.0760    0.359  141.099
# 4      -10.358       0.0333    0.040  106.976
# ...        ...          ...      ...      ...
# 2350    -2.525       0.0358    0.617   84.553
# 2351    -2.608       0.0492    0.359  116.216
# 2352    -3.416       0.0381    0.429  151.403
# 2353    -8.411       0.0328    0.730  125.994
# 2354    -9.441       0.0404    0.417  110.059
#
# [2355 rows x 18 columns]

# %%
#recombine the csvs into a dataframe 
RECOMBINE_FILES = True

path = './data' # use your path
track_files = glob.glob(path + "/tracks20*.csv")
album_files = glob.glob(path + "/albums20*.csv")

album_li = []
track_li = []
if RECOMBINE_FILES:
    for filename in album_files:
        df = pd.read_csv(filename, index_col=0, header=0, dtype=dict(albums.dtypes))
        album_li.append(df)

    album_df = pd.concat(album_li, axis=0, ignore_index=True)


    for filename in track_files:
        df = pd.read_csv(filename, index_col=0, header=0,dtype=dict(tracks.dtypes))
        track_li.append(df)

    track_df = pd.concat(track_li, axis=0, ignore_index=True)

    album_df.to_csv('./data/albums.csv')

    track_df.to_csv('./data/tracks.csv')
else:
    album_df = pd.read_csv('./data/albums.csv')
    track_df = pd.read_csv('./data/tracks.csv')

album_df = album_df.sample(frac=1).reset_index(drop=True)
track_df = track_df.sample(frac=1).reset_index(drop=True)
print(album_df)
print(track_df)
# Out:
#                   spotify_id   youtube_id             project_name  \
# 0     5fwYiohuGFqJx34Z4s26jI  42RML92tDyQ             life is good
# 1     2PPvDD3t985MvMphfSwzgr  sVKjoQMZCfU              self-titled
# 2     5RA5hhLlbw31QfQRX11pwo  t70fklNoFBI             innerspeaker
# 3     2ZjlfQheUJ8Q4MxoPruYLB  iE5p3GCzoxI              self-titled
# 4                        NaN  lMMpw5VCywc     instrumental tourist
# ...                      ...          ...                      ...
# 6973  7uDfs1lmoDlKJTGjLaipEg  p6T46TrMB80             gumboot soup
# 6974  5JXnMCR2UcTUBeKbgwNxIr  FGaO0divFf0                        v
# 6975  2xsmS7sSEtbTYv73akrN6i  ftt175Djodk      tomorrow, in a year
# 6976  2dMmcXlG8xtRJNlsjIrPWe  3CrD91zHkLg                   virtue
# 6977  3izETQ8Engz8v6Zkg0aOyX  -jvtyvMWE88  when fish ride bicycles
#
#                                 artist project_type  tracks  \
# 0                                  nas        album    18.0
# 1                             czarface        album    16.0
# 2                          tame impala        album    11.0
# 3                    all pigs must die        album     5.0
# 4        tim hecker and daniel lopatin        album    -1.0
# ...                                ...          ...     ...
# 6973  king gizzard & the lizard wizard        album    11.0
# 6974                             vreid        album     9.0
# 6975                         the knife        album    16.0
# 6976                         the voidz        album    15.0
# 6977                     the cool kids        album    11.0
#
#                                             project_art    year  rating
# 0     https://i.scdn.co/image/ab67616d000048513d9732...  2012.0     4.0
# 1     https://i.scdn.co/image/ab67616d000048516bc240...  2018.0     6.0
# 2     https://i.scdn.co/image/ab67616d00004851cd6ec1...  2010.0     6.0
# 3     https://i.scdn.co/image/ab67616d00004851049d63...  2010.0     7.0
# 4                                                   NaN    -1.0     5.0
# ...                                                 ...     ...     ...
# 6973  https://i.scdn.co/image/ab67616d000048517fe730...  2017.0     7.0
# 6974  https://i.scdn.co/image/ab67616d0000485147530a...  2012.0     6.0
# 6975  https://i.scdn.co/image/ab67616d00004851917920...  2010.0     3.0
# 6976  https://i.scdn.co/image/ab67616d00004851d00e50...  2018.0     8.0
# 6977  https://i.scdn.co/image/ab67616d00004851ef5472...  2011.0     4.0
#
# [6978 rows x 9 columns]
#                    spotify_id                album_id   youtube_id  \
# 0      62OPnFEBIWhxGX9T7s9iRx  7MvSB0JTdtl1pSwZcgvYQX  3niVOWuSVF4
# 1      2yb7WvfLS5fUMpp9W39hDy  3vfJIvgaDgTQ30UbkgIdpi  cJ5TedT9ZNA
# 2      4GvhvCrqxhpyMBUzwdDC0T  0llyIxX3nDC3hobbGibVZl  h_k1muvplJU
# 3      4hDBBUfxZom9yCl67A8UAe  25it7uSpNFuRoD6uNc0Tfu  X4UJL1V01xk
# 4      6QZfJt3Eg9qZThNVwyUCP0  2rClo2dFutwyX3N0HXaExt  BtV3qoHqVkI
# ...                       ...                     ...          ...
# 76210  2KX0Ej4HHfcpibWuHy1RBU  411nqjElDYZFaezcfWrDS3  JxVBmNpYtYM
# 76211  1D69aRJdfn6KkoqzqzTVna  6bpgmfwTWBLxT7VuS1phjL  6AVztTAVlxc
# 76212  0wmU5ejlvQighweIC7etum  1hXSxD7wpxEHXiLkk69EaQ  GUerNUwHLS0
# 76213  3mw2TRXVLKzg5MAcsRJRbw  5ZAkF7YKQI1F1M7faPYl38  zSoh4uADfus
# 76214  4WDOs6fxSHX5AMrsP52IgM  276GJQROaVFWuxjiVe0qG4  f6df3Yo-aSE
#
#                                    name  duration  explicit  \
# 0                             Wondaland  216133.0       0.0
# 1                           Waterlogged  110928.0       0.0
# 2               Reason (& Metro Boomin)  198720.0       1.0
# 3                     Happy Not Knowing  161066.0       0.0
# 4                                   Ooo  414708.0       0.0
# ...                                 ...       ...       ...
# 76210                    Joy (Idaresit)  223973.0       0.0
# 76211           Preface to a Dream Play  232008.0       0.0
# 76212              Wedding in Finistère  204680.0       0.0
# 76213               Tiny Classified Ads  112863.0       0.0
# 76214  Darkness (Dream On) F. Anna Wise  238001.0       1.0
#
#                                                  preview   key  mode  \
# 0      https://p.scdn.co/mp3-preview/5d1dbdd019fb6669...   5.0   1.0
# 1      https://p.scdn.co/mp3-preview/2d85469581a9eaa4...   0.0   1.0
# 2                                                    NaN   2.0   1.0
# 3                                                    NaN   1.0   0.0
# 4      https://p.scdn.co/mp3-preview/b63b765eb3d7107f...  11.0   1.0
# ...                                                  ...   ...   ...
# 76210  https://p.scdn.co/mp3-preview/f32914baad5e7f55...   0.0   1.0
# 76211  https://p.scdn.co/mp3-preview/078c44a562e63f05...   5.0   0.0
# 76212  https://p.scdn.co/mp3-preview/fa1d35f9d2c78cf5...   5.0   0.0
# 76213  https://p.scdn.co/mp3-preview/3ce897f7bbd1d606...   2.0   0.0
# 76214  https://p.scdn.co/mp3-preview/7ad1f2cf233919e8...   2.0   1.0
#
#        acousticness  danceability  energy  instrumentalness  liveness  \
# 0           0.01910         0.666   0.653          0.081600    0.3650
# 1           0.65500         0.451   0.949          0.001550    0.9330
# 2           0.02870         0.677   0.623          0.000089    0.1470
# 3           0.07430         0.787   0.503          0.000015    0.2870
# 4           0.37600         0.175   0.321          0.924000    0.0692
# ...             ...           ...     ...               ...       ...
# 76210       0.01300         0.613   0.763          0.061900    0.1050
# 76211       0.83400         0.126   0.389          0.042500    0.2410
# 76212       0.00757         0.824   0.627          0.000000    0.1710
# 76213       0.63400         0.475   0.718          0.000000    0.1450
# 76214       0.01490         0.533   0.850          0.002650    0.1420
#
#        loudness  speechiness  valence    tempo
# 0        -8.736       0.0315   0.6030  109.983
# 1        -6.244       0.5220   0.5390  132.296
# 2        -7.544       0.1930   0.5120  157.011
# 3        -5.230       0.0606   0.6590  100.050
# 4       -21.805       0.0865   0.0952   67.474
# ...         ...          ...      ...      ...
# 76210    -6.389       0.0366   0.4930  135.976
# 76211   -11.118       0.0354   0.1070  187.968
# 76212    -8.811       0.0437   0.8800  125.043
# 76213    -8.784       0.4630   0.5460   86.363
# 76214    -6.621       0.0791   0.2040  171.933
#
# [76215 rows x 18 columns]

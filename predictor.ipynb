# %%
#get dependencies
import numpy as np
from pyyoutube import Api
import requests as req
import re
import pandas as pd
import glob
from datetime import datetime, timezone
import logging as log
from progress.bar import Bar



VERBOSE = False
START_YEAR = 2017
END_YEAR = 2021

# %%
token_res = req.post(   'https://accounts.spotify.com/api/token', 
                        auth=('511f219d36aa49ae99789b1efd2c51c8', 'd4c2a2ce91ca43b99adc32999ad5724e'),
                        headers={
                            'content-type': 'application/x-www-form-urlencoded'
                        },
                        data={'grant_type': 'client_credentials'}
                    )
spotify_token = token_res.json()['access_token']

# %%
yt = Api(api_key='AIzaSyD_ttlnxvmdq2lTFJnUaIPeN6pI53mLjP4')

res = yt.get_channel_info(channel_name="theneedledrop")
print(res)
tnd_id = res.items[0].id

#note: youtubes api limits to 500 videos per search.


albums = pd.DataFrame(
    {'spotify_id':[],
    'youtube_id':[],
    'project_name':[],
    'artist':[],
    'project_type':[],
    'tracks':[],
    'project_art':[],
    'year':[],
    'rating':[]})

#print(albums.columns)

tracks = pd.DataFrame(
    {'spotify_id':[],
        'album_id':[],
        'youtube_id':[],
        'name':[],
        'duration':[],
        'explicit':[],
        'preview':[],
        'key':[],
        'mode':[],
        'acousticness':[],
        'danceability':[],
        'energy':[],
        'instrumentalness':[],
        'liveness':[],
        'loudness':[],
        'speechiness':[],
        'valence':[],
        'tempo':[]})

for yr in range(START_YEAR,END_YEAR+1):

    print("collecting data for " + str(yr))
    

    published_before_ts = datetime(yr+1,1,1,tzinfo=timezone.utc).isoformat()
    published_after_ts = datetime(yr,1,1,tzinfo=timezone.utc).isoformat()

    review_vids = yt.search(parts='id,snippet',
                            search_type='video',
                            channel_id=tnd_id, 
                            q='REVIEW',
                            count=500,
                            limit=500,
                            published_after=published_after_ts,
                            published_before=published_before_ts)

    bar = Bar("Processing videos", max=len(review_vids.items))
    for item in review_vids.items:

        album = {}

        vid_id = item.id.videoId
        vid = yt.get_video_by_id(video_id=vid_id).items[0]
        description = vid.snippet.description
        vid_title = vid.snippet.title.lower().split(" ")
        if 'review' not in vid_title:
            print("invalid title: " + vid.snippet.title)
            continue
        
        review_index = len(vid_title) - vid_title[::-1].index('review') - 1

        if vid_title[vid_title.index('review') - 1] in ['album','mixtape','ep','redux','complimation','soundtrack','track']:
            project_type = vid_title[review_index - 1]

            type_index = review_index - 1

            project_info = " ".join(vid_title[:type_index]).split("- ")
        else:
            project_info = " ".join(vid_title[:review_index]).split("- ")

        if len(project_info) < 2:
            print("invalid title: " + vid.snippet.title)
            continue
        artist = project_info[0].strip()
        project_name = "-".join(project_info[1::]).strip()
        rating_regex = re.search(r'\d+/10',description)
        if rating_regex:
            rating = int(rating_regex.group(0)[0:1])
        else:
            print("no rating: " + vid.snippet.title)
            continue

        

        # spotify has trouble picking up artists with ampersands in their names as well as 
        # self-titled albums, so fix the query to eliminate those errors
        search_term = ""

        search_term += " ".join(artist.replace("[","").replace("]","").replace(" X "," ").split(" & ")) + " "

        if "self-titled" in project_name:
            search_term += " " + artist
        else:
            search_term += project_name.replace("[","").replace("]","")

        if VERBOSE:
            print("searching for: " + search_term)
        

        search_res = req.get(   'https://api.spotify.com/v1/search',
                            params={
                                'q': search_term,
                                "type": "album",
                                "limit": 1,
                                'include_external': True
                            },
                            headers={
                                'authorization': "Bearer " + spotify_token
                            }
                        )
    
        album_on_spotify =  'albums' in search_res.json() and len(search_res.json()['albums']['items']) is not 0

        if not album_on_spotify:
            print("not on spotify: " + artist + " - " + project_name + " search term: " + search_term)

        if album_on_spotify:
            spotify_album = search_res.json()['albums']['items'][0]
            tracks_amt = spotify_album['total_tracks']
            release_year = int(spotify_album['release_date'][0:4])
            spotify_id = spotify_album['id']
            project_art = spotify_album['images'][-1]['url']
        
        



        
        album["spotify_id"] = spotify_id if album_on_spotify else ""
        album["youtube_id"] = vid_id
        album["project_name"] = project_name
        album["artist"] = artist
        album["project_type"] = project_type
        album["tracks"] = tracks_amt if album_on_spotify else -1
        album["project_art"] = project_art if album_on_spotify else ""
        album["year"] = release_year if album_on_spotify else -1
        album["rating"] = rating

        albums = albums.append(album,ignore_index=True)

        if VERBOSE:
            print("\033[1;30;43martist:\033[0m ", end='')
            print(artist, end=' ')
            print("\033[1;30;43mproject name:\033[0m ", end='')
            print(project_name, end=' ')
            print("\033[1;30;43mproject type:\033[0m ", end='')
            print(project_type, end=' ')


            print("\033[1;30;43mrelease year:\033[0m ", end='')
            print(release_year, end=' ')

            print("\033[1;30;43mrating:\033[0m ", end='')
            print(rating)


    

        if not album_on_spotify: continue

        #get tracks
        search_res = req.get(   'https://api.spotify.com/v1/albums/' + spotify_id + '/tracks',
                            params={
                                "limit": 50
                            },
                            headers={
                                'authorization': "Bearer " + spotify_token
                            }
                        )
        spotify_tracks = search_res.json()['items']
        

        
        for st in spotify_tracks:
            
            spotify_track_id = st['id']
            #get audio features of track
            search_res = req.get(   'https://api.spotify.com/v1/audio-features/' + spotify_track_id,
                            headers={
                                'authorization': "Bearer " + spotify_token
                            }
                        )
            has_audio_features = search_res is not None and  len(search_res.text) > 0 

            if has_audio_features:
                spotify_analysis = search_res.json()
            else:
                print("spotify audio features query failed: " + project_name)

            track = {}
            track["spotify_id"] = spotify_track_id
            track["album_id"] = spotify_id
            track["youtube_id"] = vid_id
            track["name"] = st['name']
            track["duration"] = st['duration_ms']
            track["explicit"] = st['explicit']
            track["preview"] = st['preview_url']
            track["key"] = spotify_analysis['key'] if has_audio_features and 'key' in spotify_analysis else -1
            track["mode"] = spotify_analysis['mode'] if has_audio_features and 'mode' in spotify_analysis else -1
            track["acousticness"] = spotify_analysis['acousticness'] if has_audio_features and 'acousticness' in spotify_analysis else -1
            track['danceability'] = spotify_analysis['danceability'] if has_audio_features and 'danceability' in spotify_analysis else -1
            track['energy'] = spotify_analysis['energy'] if has_audio_features and 'energy' in spotify_analysis else -1
            track['instrumentalness'] = spotify_analysis['instrumentalness'] if has_audio_features and 'instrumentalness' in spotify_analysis else -1
            track['liveness'] = spotify_analysis['liveness'] if has_audio_features and 'liveness' in spotify_analysis else -1
            track['loudness'] = spotify_analysis['loudness'] if has_audio_features and 'loudness' in spotify_analysis else -1
            track['speechiness'] = spotify_analysis['speechiness'] if has_audio_features and 'speechiness' in spotify_analysis else -1
            track['valence'] = spotify_analysis['valence'] if has_audio_features and 'valence' in spotify_analysis else -1
            track['tempo'] = spotify_analysis['tempo'] if has_audio_features and 'tempo' in spotify_analysis else -1
            

            tracks = tracks.append(track,ignore_index=True)
        
            bar.update()
            if VERBOSE:

                print("\t\033[1;30;43mtracks (" + str(tracks_amt) + "):\033[0m ")
            
                for track in tracks:
                    print("\t" + track[3], end=' ')
                    t_min_str = str(track[4] // 60000)
                    t_sec_str = "0" + str((track[4] // 1000) % 60) if (track[4] // 1000) % 60 < 10 else str((track[4] // 1000) % 60)
                    print("(" + t_min_str + ":" + t_sec_str + ")", end=' ')
                    
                    track_key = ["C", "C#", "D", "D#", "E", "F", "F#", "G", "G#", "A", "A#", "B"][track[7]] if track[7] != -1 else "unknown"
                    print("\033[1;30;43mkey:\033[0m ",end='')
                    print(track_key, end=' ')

                    track_mode = "major" if track[8] == 1 else "minor"
                    print("\033[1;30;43mmode:\033[0m ",end='')
                    print(track_mode)
            
    bar.finish()
    #save to tracks.csv
    print(albums)
    print(tracks)
    tracks.to_csv('./data/tracks' + str(yr) + '.csv')
    albums.to_csv('./data/albums' + str(yr) + '.csv')
# Out:
# ChannelListResponse(kind='youtube#channelListResponse')
# collecting data for 2016
# no rating: Nas - Illmatic ALBUM REVIEW
# no rating: Nirvana - In Utero ALBUM REVIEW
# no rating: Radiohead - Kid A ALBUM REVIEW
# spotify audio features query failed: 24k magic
# spotify audio features query failed: 24k magic
# spotify audio features query failed: 24k magic
# no rating: Yes - Close to the Edge ALBUM REVIEW
# spotify audio features query failed: paidprogramming2
# spotify audio features query failed: paidprogramming2
# spotify audio features query failed: paidprogramming2
# spotify audio features query failed: paidprogramming2
# no rating: DJ Shadow - Endtroducing..... ALBUM REVIEW
# no rating: Childish Gambino - Awaken, My Love! ALBUM REVIEW
# invalid title: kendrick lamar untitled unmastered. review | 03.06.16.mov
# spotify audio features query failed: vroom vroom
# no rating: The Microphones - The Glow Pt. 2 ALBUM REVIEW
# no rating: Kanye West - "Real Friends" TRACK REVIEW
# spotify audio features query failed: holy ghost
# spotify audio features query failed: spirit phone
# spotify audio features query failed: spirit phone
# no rating: Blank Banshee - MEGA ALBUM REVIEW
# spotify audio features query failed: lil boat
# spotify audio features query failed: lil boat
# spotify audio features query failed: lil boat
# spotify audio features query failed: floss
# no rating: David Bowie - The Rise and Fall of Ziggy Stardust and the Spiders from Mars ALBUM REVIEW
# spotify audio features query failed: lil big pac
# spotify audio features query failed: lil big pac
# spotify audio features query failed: worry
# spotify audio features query failed: worry
# no rating: Kanye West - "No More Parties In LA" ft. Kendrick Lamar TRACK REVIEW
# spotify audio features query failed: wildflower
# spotify audio features query failed: wildflower
# spotify audio features query failed: wildflower
# spotify audio features query failed: wildflower
# spotify audio features query failed: we got it from here... thank you 4 your service
# spotify audio features query failed: we got it from here... thank you 4 your service
# spotify audio features query failed: warlord
# spotify audio features query failed: run the jewels 3
# spotify audio features query failed: run the jewels 3
# spotify audio features query failed: junk
# spotify audio features query failed: junk
# spotify audio features query failed: junk
# spotify audio features query failed: junk
# invalid title: Drake - "Pop Style" and "One Dance" TRACK REVIEWS
# spotify audio features query failed: the hope six demolition project
# spotify audio features query failed: the hope six demolition project
# no rating: Post Malone - August 26th MIXTAPE REVIEW
# spotify audio features query failed: nattesferd
# spotify audio features query failed: nattesferd
# spotify audio features query failed: nattesferd
# spotify audio features query failed: nattesferd
# spotify audio features query failed: nattesferd
# spotify audio features query failed: passion, pain & demon slayin'
# spotify audio features query failed: passion, pain & demon slayin'
# spotify audio features query failed: passion, pain & demon slayin'
# spotify audio features query failed: the dream is over
# spotify audio features query failed: the dream is over
# no rating: The Avalanches - Frankie Sinatra ft. Danny Brown & MF DOOM TRACK REVIEW
# spotify audio features query failed: a seat at the table
# no rating: Macklemore & Ryan Lewis - "White Privilege II" ft. Jamila Woods TRACK REVIEW
# spotify audio features query failed: bobby tarantino
# spotify audio features query failed: bobby tarantino
# invalid title: TOP 10 WORST ALBUMS OF 2016
# spotify audio features query failed: yes lawd!
# spotify audio features query failed: yes lawd!
# spotify audio features query failed: yes lawd!
# no rating: Patti Smith - Horses ALBUM REVIEW
# spotify audio features query failed: the divine feminine
# spotify audio features query failed: body war
# spotify audio features query failed: southern family compilation
# spotify audio features query failed: southern family compilation
# spotify audio features query failed: sleep cycle
# spotify audio features query failed: amnesty (i)
# spotify audio features query failed: amnesty (i)
# spotify audio features query failed: pool
# no rating: Dinosaur Jr. - Give A Glimpse of What Yer Not ALBUM REVIEW
# spotify audio features query failed: wriggle
# spotify audio features query failed: wriggle
# spotify audio features query failed: wriggle
# spotify audio features query failed: 32 levels
# spotify audio features query failed: 32 levels
# spotify audio features query failed: 32 levels
# spotify audio features query failed: 32 levels
# spotify audio features query failed: 32 levels
# spotify audio features query failed: life of pause
# not on spotify: 2 8 1 4 - rain temple search term: 2 8 1 4 rain temple
# spotify audio features query failed: p3
# spotify audio features query failed: p3
# spotify audio features query failed: my woman
# spotify audio features query failed: painting with
# spotify audio features query failed: painting with
# spotify audio features query failed: a.i.m.
# spotify audio features query failed: a.i.m.
# spotify audio features query failed: a.i.m.
# no rating: De La Soul - And The Anonymous Nobody ALBUM REVIEW
# spotify audio features query failed: the bible 2
# spotify audio features query failed: how to be a human being
# spotify audio features query failed: telefone
# spotify audio features query failed: telefone
# spotify audio features query failed: the sun's tirade
# spotify audio features query failed: the sun's tirade
# spotify audio features query failed: bbf (hosted by dj escrow)
# spotify audio features query failed: bbf (hosted by dj escrow)
# invalid title: Meshuggah's The Violent Sleep of Reason: NOT GOOD
# spotify audio features query failed: human performance
# no rating: Metá Metá - MM3 ALBUM REVIEW
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: everybody looking
# spotify audio features query failed: konnichiwa
# invalid title: Post Malone's Stoney: NOT GOOD
# spotify audio features query failed: nonagon infinity
# spotify audio features query failed: too high to riot
# spotify audio features query failed: handshakes with snakes
# spotify audio features query failed: handshakes with snakes
# spotify audio features query failed: handshakes with snakes
# no rating: $uicideboy$ - Eternal Grey ALBUM REVIEW
# no rating: Gonjasufi - Callus ALBUM REVIEW
# spotify audio features query failed: 99.9%
# spotify audio features query failed: 99.9%
# spotify audio features query failed: 99.9%
# spotify audio features query failed: 99.9%
# spotify audio features query failed: 99.9%
# spotify audio features query failed: 99.9%
# spotify audio features query failed: 99.9%
# spotify audio features query failed: negus
# spotify audio features query failed: negus
# spotify audio features query failed: negus
# spotify audio features query failed: iv
# spotify audio features query failed: iv
# spotify audio features query failed: iv
# spotify audio features query failed: iv
# spotify audio features query failed: iv
# spotify audio features query failed: iv
# no rating: Ty Dolla $ign - Campaign MIXTAPE REVIEW
# invalid title: THE WORST ALBUM OF 2016 (Corey Feldman's Angelic 2 The Core) [NOT GOOD]
# spotify audio features query failed: slime season 3
# spotify audio features query failed: slime season 3
# spotify audio features query failed: slime season 3
# spotify audio features query failed: slime season 3
# spotify audio features query failed: slime season 3
# spotify audio features query failed: värähtelijä
# spotify audio features query failed: värähtelijä
# spotify audio features query failed: värähtelijä
# spotify audio features query failed: värähtelijä
# spotify audio features query failed: värähtelijä
# spotify audio features query failed: värähtelijä
# spotify audio features query failed: always strive and prosper
# spotify audio features query failed: always strive and prosper
# spotify audio features query failed: always strive and prosper
# spotify audio features query failed: always strive and prosper
# spotify audio features query failed: always strive and prosper
# spotify audio features query failed: always strive and prosper
# spotify audio features query failed: i like it when you sleep, for you are so beautiful yet so unaware of it
# spotify audio features query failed: i like it when you sleep, for you are so beautiful yet so unaware of it
# spotify audio features query failed: i like it when you sleep, for you are so beautiful yet so unaware of it
# spotify audio features query failed: i like it when you sleep, for you are so beautiful yet so unaware of it
# spotify audio features query failed: feelin' kinda free
# spotify audio features query failed: feelin' kinda free
# spotify audio features query failed: feelin' kinda free
# spotify audio features query failed: dystopia
# spotify audio features query failed: dystopia
# spotify audio features query failed: dystopia
# spotify audio features query failed: dystopia
# spotify audio features query failed: the long dark blue
# spotify audio features query failed: the long dark blue
# spotify audio features query failed: the long dark blue
# spotify audio features query failed: the perfect luv tape
# spotify audio features query failed: the perfect luv tape
# not on spotify: lil yachty - summer songs 2 mixtape or search term: lil yachty summer songs 2 mixtape or
# spotify audio features query failed: leave me alone
# spotify audio features query failed: leave me alone
# spotify audio features query failed: leave me alone
# no rating: Deathspell Omega - The Synarchy of Molten Bones ALBUM REVIEW
# invalid title: YUNOREVIEW: OCTOBER 2016
# spotify audio features query failed: prima donna
# spotify audio features query failed: prima donna
# spotify audio features query failed: at least for now
# spotify audio features query failed: at least for now
# spotify audio features query failed: at least for now
# spotify audio features query failed: at least for now
# spotify audio features query failed: at least for now
# no rating: Kanye West - "Facts" TRACK REVIEW
# not on spotify: a$ap mob - the cozy tapes vol. 1: friends- search term: a$ap mob the cozy tapes vol. 1: friends-
# not on spotify: case / lang / veirs - self-titled search term: case / lang / veirs  case / lang / veirs
# spotify audio features query failed: iv
# spotify audio features query failed: iv
# spotify audio features query failed: coloring book
# no rating: Joey Bada$$ - "Ready" (prod. Statik Selektah) TRACK REVIEW
# spotify audio features query failed: stage four
# invalid title: Blink-182's California: NOT GOOD
# spotify audio features query failed: skeleton tree
# spotify audio features query failed: emotion: side b
# spotify audio features query failed: emotion: side b
# spotify audio features query failed: emotion: side b
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: honor killed the samurai
# no rating: Beyoncé - "Formation" TRACK REVIEW
# spotify audio features query failed: telefone
# spotify audio features query failed: 3001: a laced odyssey
# spotify audio features query failed: 3001: a laced odyssey
# spotify audio features query failed: a fistful of peril
# spotify audio features query failed: feelin' kinda free
# spotify audio features query failed: the colour in anything
# spotify audio features query failed: the colour in anything
# spotify audio features query failed: the colour in anything
# spotify audio features query failed: the colour in anything
# spotify audio features query failed: self-titled (lp2)
# spotify audio features query failed: self-titled (lp2)
# spotify audio features query failed: self-titled (lp2)
# spotify audio features query failed: the bride
# spotify audio features query failed: the bride
# spotify audio features query failed: the bride
# spotify audio features query failed: the bride
# spotify audio features query failed: hyperion
# spotify audio features query failed: rheia
# spotify audio features query failed: rheia
# spotify audio features query failed: rheia
# spotify audio features query failed: stage four
# spotify audio features query failed: bonito generation
# spotify audio features query failed: bonito generation
# spotify audio features query failed: bonito generation
# spotify audio features query failed: made in the manor
# no rating: Roy Woods - Waking At Dawn ALBUM REVIEW
# spotify audio features query failed: the healing component
# spotify audio features query failed: hopelessness
# spotify audio features query failed: black america again
# spotify audio features query failed: black america again
# spotify audio features query failed: black america again
# spotify audio features query failed: mind of mine
# spotify audio features query failed: mind of mine
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# no rating: $uicideBoy$ - Radical $uicide EP REVIEW
# spotify audio features query failed: the ghosts of highway 20
# spotify audio features query failed: the ghosts of highway 20
# spotify audio features query failed: the ghosts of highway 20
# spotify audio features query failed: the ghosts of highway 20
# spotify audio features query failed: the ghosts of highway 20
# spotify audio features query failed: innocence reaches
# invalid title: 21 Savage and Metro Boomin's Savage Mode: NOT GOOD
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: los suicidas
# no rating: Tobacco - Sweatbox Dynasty ALBUM REVIEW
# spotify audio features query failed: tell me i'm pretty
# spotify audio features query failed: tell me i'm pretty
# spotify audio features query failed: 1992
# spotify audio features query failed: 1992
# spotify audio features query failed: 1992
# spotify audio features query failed: aa
# spotify audio features query failed: aa
# spotify audio features query failed: aa
# spotify audio features query failed: aa
# spotify audio features query failed: aa
# spotify audio features query failed: voices
# spotify audio features query failed: voices
# spotify audio features query failed: voices
# spotify audio features query failed: voices
# spotify audio features query failed: voices
# spotify audio features query failed: voices
# spotify audio features query failed: voices
# spotify audio features query failed: voices
# invalid title: Star Wars Head Space VARIOUS ARTISTS COMPILATION REVIEW
# spotify audio features query failed: all your happy life
# spotify audio features query failed: all your happy life
# spotify audio features query failed: all your happy life
# spotify audio features query failed: i'm up
# spotify audio features query failed: i'm up
# no rating: Lil Ugly Mane - Oblivion Access ALBUM REVIEW
# invalid title: YUNOREVIEW: JULY 2016
# spotify audio features query failed: fires within fires
# spotify audio features query failed: the impossible kid
# spotify audio features query failed: the impossible kid
# spotify audio features query failed: the impossible kid
# invalid title: B.o.B - "Flatline" & Tyson - "Flat to Fact" TRACK REVIEWS
# no rating: Lil Ugly Mane - Oblivion Access ALBUM REVIEW
# invalid title: YUNOREVIEW: JULY 2016
# invalid title: B.o.B - "Flatline" & Tyson - "Flat to Fact" TRACK REVIEWS
# spotify audio features query failed: hymns
# spotify audio features query failed: hymns
# not on spotify: boots - aquʌria search term: boots aquʌria
# invalid title: Weezer's Blue Album Is Better Than Pinkerton
# invalid title: YUNOREVIEW: APRIL 2016
# spotify audio features query failed: love streams
# spotify audio features query failed: love streams
# invalid title: The Strokes - Future Present Past EP
# no rating: Death Grips - More Than The Fairy ft. Les Claypool TRACK REVIEW
# spotify audio features query failed: end position
# spotify audio features query failed: the magic
# spotify audio features query failed: the magic
# spotify audio features query failed: the magic
# spotify audio features query failed: the magic
# spotify audio features query failed: blank face
# spotify audio features query failed: adore life
# no rating: Ghost - Popestar EP REVIEW
# spotify audio features query failed: is the is are
# spotify audio features query failed: moth
# spotify audio features query failed: plays the music of twin peaks
# no rating: Thee Oh Sees - An Odd Entrances ALBUM REVIEW
# spotify audio features query failed: the terrible tales of scurvy jones
# spotify audio features query failed: the terrible tales of scurvy jones
# spotify audio features query failed: dungeon bastards
# spotify audio features query failed: dungeon bastards
# spotify audio features query failed: schmilco
# invalid title: CHANNEL SUPPORT & CLASSIC REVIEW UPDATE!
# spotify audio features query failed: this unruly mess i've made
# spotify audio features query failed: this unruly mess i've made
# invalid title: Skillet's Unleashed: NOT GOOD
# spotify audio features query failed: i aka i
# spotify audio features query failed: i aka i
# spotify audio features query failed: before a million universes
# invalid title: Desiigner's New English: NOT GOOD
# spotify audio features query failed: do what thou wilt.
# spotify audio features query failed: do what thou wilt.
# spotify audio features query failed: metal resistance
# spotify audio features query failed: metal resistance
# spotify audio features query failed: metal resistance
# spotify audio features query failed: metal resistance
# spotify audio features query failed: metal resistance
# invalid title: YUNOREVIEW: MAY 2016
# spotify audio features query failed: city sun eater in the river of light
# spotify audio features query failed: city sun eater in the river of light
# spotify audio features query failed: city sun eater in the river of light
# spotify audio features query failed: city sun eater in the river of light
# invalid title: YUNOREVIEW: SEPTEMBER 2016
# invalid title: I don't want another Madvillain album!
# invalid title: Trisha Paytas' Showtime EP: NOT GOOD
# invalid title: Vinyl Update: 03-05-16
# not on spotify: the body and full of hell - one day you will ache like i ache search term: the body and full of hell one day you will ache like i ache
# no rating: Brain Tentacles - Self-Titled ALBUM REVIEW
# invalid title: Top 15 WORST SONGS OF 2016
# invalid title: YUNOREVIEW: AUGUST 2016
# invalid title: YUNOREVIEW: MARCH 2016
# invalid title: Vinyl Update: 07-05-16
# invalid title: YUNOREVIEW: JAN 2016
# invalid title: FAV & WORST TRACKS: 8/7 (Suicide Squad OST, Alcest, Norah Jones, E-40)
# invalid title: On Track with The Needle Drop – Danny Brown
# invalid title: Vinyl Update: 10-15-16 (Bob Dylan, Talking Heads, GG Allin, The Germs)
# invalid title: YUNOREVIEW: FEB 2016
# invalid title: YUNOREVIEW: JUNE 2016
# invalid title: SiIvagunner, BlurryShrek, Cringecore Hip Hop - IT CAME FROM BANDCAMP
# invalid title: BEST & WORST TRACKS: 10/30 (A$AP Rocky, Drake, Pussy Riot, Charli XCX)
# invalid title: HARAMBE METAL - It Came From Bandcamp
# invalid title: Changing The Life of Pablo (Should albums be altered?)
# invalid title: TND Podcast #34 The politics of contemporary reviews and thinkpieces
# invalid title: Top 15 EPs of 2016
# invalid title: BEST & WORST TRACKS: 9/25 (The Weeknd, Pink Guy, Scarlett Johansson, Leonard Cohen)
# invalid title: Vinyl Update: 04-28-16
# invalid title: BEST & WORST TRACKS: 11/27 (Childish Gambino, Yung Lean, Macklemore, Flatbush Zombies)
# invalid title: BEST & WORST TRACKS: 10/23 (Action Bronson, Eminem, The Flaming Lips, Le Tigre)
# invalid title: Tove Lo's Lady Wood: NOT GOOD
# invalid title: TND Podcast #44 ft. Daveed Diggs
# invalid title: BEST & WORST TRACKS: 11/14 (Childish Gambino, Run the Jewels, The xx, Okilly Dokilly)
# invalid title: TND Podcast #54 ft. Adam of YourMovieSucks
# invalid title: GREAT ALBUMS: MAY 2016
# invalid title: Great Albums: August 2016
# invalid title: "NORF NORF" Lady Upset by Vince Staples Lyrics
# invalid title: Death Grips - Bottomless Pit LYRIC READ-ALONG ft. Dominick Rabrun
# invalid title: FAV TRACKS: 6/20 (Danny Brown, The Avalanches, Hot Dad)
# invalid title: GREAT ALBUMS: FEB 2016
# invalid title: GREAT ALBUMS: MARCH 2016
# invalid title: GREAT ALBUMS: JULY 2016
# invalid title: GREAT ALBUMS: October 2016
# invalid title: GREAT ALBUMS: NOVEMBER 2016
# invalid title: GREAT ALBUMS: APRIL 2016
# invalid title: GREAT ALBUMS: September 2016
# invalid title: IT CAME FROM BANDCAMP (JULY 2016)
# invalid title: FAV & WORST TRACKS: 8/21 (Danny Brown, Metallica, Crystal Castles, Isaiah Rashad)
# invalid title: HONORABLE MENTIONS 2016
# invalid title: BEST & WORST TRACKS: 12/4 (Kid Cudi, J. Cole, Run the Jewels, Young M.A)
# invalid title: TND Podcast #42 ft. Digibro
# invalid title: CAL CHUCHESTA MUSIC SPEXIAL OF 2015 MUSCI YOUTUBE.COM/THENEEDLEDROP SPONSORED BY GOOGLE! (2015!)
# invalid title: TND Podcast #41 ft. Matmos
# invalid title: TND Podcast #55: clipping. Live Interview @ S.O.S. Fest
# invalid title: IT CAME FROM BANDCAMP! (May 2016)
# invalid title: RECORD STORE DAY 2016 PICKS!!!!
# invalid title: TND Podcast #37 ft. Full of Hell's Spencer Hazard
# invalid title: Vinyl Update: 08-15-16 (Death Grips, Kendrick Lamar, Dream Catalogue, Bob Dylan)
# invalid title: IT CAME FROM BANDCAMP! (APRIL 2016)
# invalid title: Albums I'm Anticipating In 2016!!!
# invalid title: IT CAME FROM BANDCAMP! (June 2016)
# invalid title: TND Podcast #50 ft. Anthony Fantano
# invalid title: BEST & WORST TRACKS: 12/11 (Ab-Soul, Lil Yachty, At the Drive-In, YG, Zayn, Taylor Swift)
# invalid title: Top 50 Singles of 2016
# invalid title: TND Podcast #35 ft. Dr. Michael Greger
# invalid title: 30 Songs For a Trump-Free America, and Political Music in 2016
# invalid title: TND Podcast #52 ft. Pyrocynical and NFKRZ
# invalid title: On Track with the Needle Drop – Alice Cooper
# invalid title: TND Podcast #46 ft. Tim Hecker
# invalid title: TND Podcast #49 ft. Evan Puschak (a.k.a. Nerdwriter)
# invalid title: TND Podcast #43 ft. Mitch Grassi
# invalid title: TND Podcast #51 ft. Xenia Rubinos
# invalid title: TND Podcast #45 ft. FrankJavCee
# invalid title: TND Podcast #53 ft. Miles Cleret of Soundway Records
# invalid title: TND Podcast #48 ft. Marissa Nadler
# invalid title: BEST & WORST TRACKS: 8/28 (Carly Rae Jepsen, Sum 41, Thundercat)
# invalid title: BEST & WORST TRACKS: 11/6 (Lena Dunham, Big Sean, Future, Drake, Kevin Abstract)
# invalid title: BEST & WORST TRACKS: 10/9 (Lady Gaga, Bruno Mars, Sleigh Bells, Zeds Dead)
# invalid title: TND Podcast #39 ft. Maddox
# invalid title: BEST & WORST TRACKS: 10/2 (Kid Cudi, Korn, The Weeknd, Captain Murphy)
# invalid title: FAV TRACKS: 7/10 (Gucci Mane, Lil Yachty, Arca, Iglooghost)
# invalid title: FAV TRACKS: 7/3 (ScHoolboy Q, BADBADNOTGOOD, Angel Olsen)
# invalid title: FAV & WORST TRACKS: 7/17 (Justice, Good Charlotte, Migos, Katy Perry)
# invalid title: BEST & WORST TRACKS: 10/16 (Maroon 5, Macklemore, Foxygen, NxWorries, Rich Chigga)
# invalid title: FAV TRACKS: 6/26 (Sigur Rós, Touché Amoré, Gucci Mane, The Tallest Man On Earth)
# invalid title: FAV & WORST TRACKS: 7/31 (Mac Miller, clipping. and DJ Khaled)
# invalid title: BEST & WORST TRACKS: 9/18 (Justice, Kim Gordon, OG Maco, Justin Timberlake, Ghost)
#                  spotify_id   youtube_id  \
# 0    3mH6qwIy9crq0I9YQbOuDf  iKvC10hmVnU
# 1    7EpUpNUkkEGnaCvkcn1j4H  GloclhybVlQ
# 2    2w1YJXWMIco6EBf0CovvVN  AZD9mJ_yGIQ
# 3    7dK54iZuOxXFarGhXwEXfF  mkUxFB6jbDc
# 4    67hzZ19BcqT086ahgI9DIB  kAOw5dpeaus
# ..                      ...          ...
# 182  1b4pVloeDH3lsMp1yTeeA4  VhZH6xAzlY8
# 183  1CEeqK9sKrE7LzUHeT3bfP  W4A0ViBBnrk
# 184  4SPPYbkkYYAIWlBiGEkR96  GlAsfhqp7E8
# 185  1LGBxdl9JbgEn0cuaVJRUY  LKQqAr4D9Qg
# 186                          cGmrG1JAYaQ
#
#                              project_name                     artist  \
# 0                                  blonde                frank ocean
# 1                                 jeffery                 young thug
# 2                           ★ (blackstar)                david bowie
# 3                                lemonade                    beyoncé
# 4                             ruminations               conor oberst
# ..                                    ...                        ...
# 182                              paradise                  pop. 1280
# 183                    do what thou wilt.                    ab-soul
# 184                      metal resistance                  babymetal
# 185  city sun eater in the river of light                      woods
# 186     one day you will ache like i ache  the body and full of hell
#
#     project_type  tracks                                        project_art  \
# 0          album    17.0  https://i.scdn.co/image/ab67616d00004851c5649a...
# 1        mixtape    10.0  https://i.scdn.co/image/ab67616d00004851d0c722...
# 2          album     7.0  https://i.scdn.co/image/ab67616d000048514ff4ce...
# 3          album    13.0  https://i.scdn.co/image/ab67616d0000485189992f...
# 4          album    10.0  https://i.scdn.co/image/ab67616d00004851bfac3a...
# ..           ...     ...                                                ...
# 182        album     9.0  https://i.scdn.co/image/ab67616d00004851ac0520...
# 183        album    16.0  https://i.scdn.co/image/ab67616d00004851538039...
# 184        album    12.0  https://i.scdn.co/image/ab67616d00004851c2e07e...
# 185        album    10.0  https://i.scdn.co/image/ab67616d000048511fe0a3...
# 186        album    -1.0
#
#        year  rating
# 0    2016.0     8.0
# 1    2016.0     7.0
# 2    2016.0     9.0
# 3    2016.0     8.0
# 4    2016.0     8.0
# ..      ...     ...
# 182  2016.0     8.0
# 183  2016.0     7.0
# 184  2016.0     6.0
# 185  2016.0     7.0
# 186    -1.0     7.0
#
# [187 rows x 9 columns]
#                   spotify_id                album_id   youtube_id  \
# 0     19YKaevk2bce4odJkP5L22  3mH6qwIy9crq0I9YQbOuDf  iKvC10hmVnU
# 1     2ZWlPOoWh0626oTaHrnl2a  3mH6qwIy9crq0I9YQbOuDf  iKvC10hmVnU
# 2     3xKsf9qdS1CyvXSMEid6g8  3mH6qwIy9crq0I9YQbOuDf  iKvC10hmVnU
# 3     1IdZvb2XK8NmsovQlV6CPn  3mH6qwIy9crq0I9YQbOuDf  iKvC10hmVnU
# 4     35xSkNIXi504fcEwz9USRB  3mH6qwIy9crq0I9YQbOuDf  iKvC10hmVnU
# ...                      ...                     ...          ...
# 2203  6OCHsW7desiRWCFJFDozNQ  1LGBxdl9JbgEn0cuaVJRUY  LKQqAr4D9Qg
# 2204  5YjtMnSe4lhAP6Aa6kSnyH  1LGBxdl9JbgEn0cuaVJRUY  LKQqAr4D9Qg
# 2205  1rUMZ0CMfgNt0GBXFnZi3S  1LGBxdl9JbgEn0cuaVJRUY  LKQqAr4D9Qg
# 2206  1Zo3v8Eg1Ey8Uz6u2syxeW  1LGBxdl9JbgEn0cuaVJRUY  LKQqAr4D9Qg
# 2207  1czgPPmVxvqMvIryeDtnj7  1LGBxdl9JbgEn0cuaVJRUY  LKQqAr4D9Qg
#
#                    name  duration  explicit  \
# 0                 Nikes  314075.0       1.0
# 1                   Ivy  249191.0       1.0
# 2          Pink + White  184516.0       0.0
# 3           Be Yourself   86943.0       0.0
# 4                  Solo  257380.0       1.0
# ...                 ...       ...       ...
# 2203           The Take  337026.0       0.0
# 2204  I See in the Dark  245816.0       0.0
# 2205   Politics of Free  216230.0       0.0
# 2206     The Other Side  244324.0       0.0
# 2207        Hollow Home  245099.0       0.0
#
#                                                 preview  key  mode  \
# 0     https://p.scdn.co/mp3-preview/be2bc4aadde588c1...  8.0   1.0
# 1     https://p.scdn.co/mp3-preview/1faa6f5d71e4993a...  9.0   0.0
# 2     https://p.scdn.co/mp3-preview/3ebaac6d4686eea3...  9.0   1.0
# 3     https://p.scdn.co/mp3-preview/770828645fd1d35e...  7.0   1.0
# 4     https://p.scdn.co/mp3-preview/44b018025d71c874...  5.0   0.0
# ...                                                 ...  ...   ...
# 2203  https://p.scdn.co/mp3-preview/92ec4b27756a4032... -1.0  -1.0
# 2204  https://p.scdn.co/mp3-preview/5e87b6b64da65d86...  9.0   0.0
# 2205  https://p.scdn.co/mp3-preview/de07c234884ffe35...  2.0   1.0
# 2206  https://p.scdn.co/mp3-preview/80b994e282209752...  9.0   0.0
# 2207  https://p.scdn.co/mp3-preview/06802414adb9a22e...  6.0   0.0
#
#       acousticness  danceability  energy  instrumentalness  liveness  \
# 0           0.6950         0.543   0.394          0.000239    0.1080
# 1           0.7820         0.567   0.388          0.000309    0.2480
# 2           0.6700         0.544   0.552          0.000046    0.4150
# 3           0.9850         0.657   0.431          0.000000    0.1490
# 4           0.8490         0.444   0.287          0.000003    0.1610
# ...            ...           ...     ...               ...       ...
# 2203       -1.0000        -1.000  -1.000         -1.000000   -1.0000
# 2204        0.0421         0.637   0.606          0.542000    0.0814
# 2205        0.0147         0.701   0.810          0.000448    0.0976
# 2206        0.1040         0.607   0.585          0.000000    0.0966
# 2207        0.1780         0.562   0.755          0.634000    0.1370
#
#       loudness  speechiness  valence    tempo
# 0       -9.637       0.0864    0.118  137.811
# 1       -9.579       0.0384    0.452  116.362
# 2       -7.450       0.0991    0.554  159.738
# 3      -11.147       0.5410    0.935   83.509
# 4      -10.631       0.0375    0.246  124.027
# ...        ...          ...      ...      ...
# 2203    -1.000      -1.0000   -1.000   -1.000
# 2204    -6.684       0.0413    0.678  145.477
# 2205    -6.040       0.0369    0.900  122.992
# 2206    -6.975       0.0297    0.868  125.233
# 2207    -6.771       0.0295    0.882  145.057
#
# [2208 rows x 18 columns]
# collecting data for 2017
# spotify audio features query failed: revival
# spotify audio features query failed: revival
# spotify audio features query failed: revival
# spotify audio features query failed: revival
# spotify audio features query failed: revival
# spotify audio features query failed: revival
# invalid title: Anthony Fantano HUMAN BEING REVIEW (1 Million Subscriber Special)
# spotify audio features query failed: luv is rage 2
# spotify audio features query failed: luv is rage 2
# spotify audio features query failed: luv is rage 2
# no rating: Pink Guy - Pink Season ALBUM REVIEW
# spotify audio features query failed: damn.
# spotify audio features query failed: flower boy
# spotify audio features query failed: flower boy
# spotify audio features query failed: flower boy
# spotify audio features query failed: 17
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# no rating: Gorillaz - Humanz ALBUM REVIEW
# spotify audio features query failed: 4:44
# spotify audio features query failed: 4:44
# spotify audio features query failed: 4:44
# spotify audio features query failed: reputation
# no rating: Playboi Carti - Self-Titled MIXTAPE REVIEW
# spotify audio features query failed: orc
# spotify audio features query failed: science fiction
# spotify audio features query failed: everything now
# no rating: Kendrick Lamar - HUMBLE. TRACK REVIEW
# spotify audio features query failed: saturation
# spotify audio features query failed: saturation
# spotify audio features query failed: saturation
# spotify audio features query failed: saturation
# spotify audio features query failed: saturation
# not on spotify: neil cicierega - mouth moods search term: neil cicierega mouth moods
# spotify audio features query failed: issa album
# spotify audio features query failed: teenage emotions
# spotify audio features query failed: teenage emotions
# spotify audio features query failed: all-amerikkkan bada$$
# spotify audio features query failed: all-amerikkkan bada$$
# spotify audio features query failed: all-amerikkkan bada$$
# spotify audio features query failed: divide
# spotify audio features query failed: divide
# spotify audio features query failed: rainbow
# spotify audio features query failed: rainbow
# no rating: Outkast - ATLiens ALBUM REVIEW
# spotify audio features query failed: take me apart
# spotify audio features query failed: take me apart
# spotify audio features query failed: take me apart
# spotify audio features query failed: take me apart
# spotify audio features query failed: take me apart
# spotify audio features query failed: take me apart
# spotify audio features query failed: savage sinusoid
# spotify audio features query failed: savage sinusoid
# spotify audio features query failed: savage sinusoid
# spotify audio features query failed: masseduction
# no rating: Gucci Mane & Metro Boomin - Drop Top Wop MIXTAPE REVIEW
# invalid title: Kanye West: Worst To Best
# spotify audio features query failed: thrice woven
# no rating: Joji - In Tongues EP REVIEW
# spotify audio features query failed: who built the moon?
# spotify audio features query failed: who built the moon?
# spotify audio features query failed: culture
# spotify audio features query failed: culture
# spotify audio features query failed: culture
# spotify audio features query failed: culture
# spotify audio features query failed: culture
# spotify audio features query failed: culture
# spotify audio features query failed: culture
# spotify audio features query failed: culture
# spotify audio features query failed: goths
# spotify audio features query failed: goths
# spotify audio features query failed: goths
# spotify audio features query failed: goths
# no rating: At the Drive-In - in•ter a•li•a ALBUM REVIEW
# spotify audio features query failed: rap album two
# spotify audio features query failed: rap album two
# spotify audio features query failed: forced witness
# spotify audio features query failed: forced witness
# spotify audio features query failed: peasant
# spotify audio features query failed: polygondwanaland
# spotify audio features query failed: polygondwanaland
# no rating: Captain Beefheart - Trout Mask Replica ALBUM REVIEW
# spotify audio features query failed: villains
# spotify audio features query failed: villains
# spotify audio features query failed: cozy tapes vol. 2: too cozy
# spotify audio features query failed: cozy tapes vol. 2: too cozy
# spotify audio features query failed: packs
# spotify audio features query failed: packs
# spotify audio features query failed: freudian
# spotify audio features query failed: freudian
# spotify audio features query failed: freudian
# spotify audio features query failed: freudian
# spotify audio features query failed: lust for life
# spotify audio features query failed: lust for life
# spotify audio features query failed: lust for life
# spotify audio features query failed: lust for life
# spotify audio features query failed: saturation ii
# spotify audio features query failed: saturation ii
# spotify audio features query failed: saturation ii
# spotify audio features query failed: saturation ii
# spotify audio features query failed: saturation ii
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# invalid title: YUNOREVIEW: June 2017 (Big Boi, Royal Blood, Pond, Halsey + More!)
# spotify audio features query failed: emperor of sand
# spotify audio features query failed: emperor of sand
# spotify audio features query failed: emperor of sand
# spotify audio features query failed: emperor of sand
# spotify audio features query failed: emperor of sand
# spotify audio features query failed: rainbow mirror
# spotify audio features query failed: rainbow mirror
# spotify audio features query failed: rainbow mirror
# spotify audio features query failed: rainbow mirror
# no rating: Calvin Harris - Funk Wav Bounces Vol. 1 ALBUM REVIEW
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# no rating: Bryson Tiller - True to Self ALBUM REVIEW
# no rating: Bleachers - Gone Now ALBUM REVIEW
# spotify audio features query failed: no dope on sundays
# spotify audio features query failed: no dope on sundays
# spotify audio features query failed: no dope on sundays
# spotify audio features query failed: no dope on sundays
# spotify audio features query failed: no dope on sundays
# spotify audio features query failed: no dope on sundays
# no rating: Death Grips - Steroids (Crouching Tiger Hidden Gabber Megamix) EP REVIEW
# no rating: Wavves - You're Welcome ALBUM REVIEW
# spotify audio features query failed: murder of the universe
# spotify audio features query failed: murder of the universe
# spotify audio features query failed: murder of the universe
# spotify audio features query failed: murder of the universe
# spotify audio features query failed: murder of the universe
# spotify audio features query failed: murder of the universe
# spotify audio features query failed: murder of the universe
# spotify audio features query failed: boy who cried wolf
# spotify audio features query failed: boy who cried wolf
# spotify audio features query failed: boy who cried wolf
# spotify audio features query failed: boy who cried wolf
# spotify audio features query failed: boy who cried wolf
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: big fish theory
# spotify audio features query failed: big fish theory
# spotify audio features query failed: big fish theory
# spotify audio features query failed: big fish theory
# spotify audio features query failed: pleasure
# spotify audio features query failed: pleasure
# spotify audio features query failed: pleasure
# spotify audio features query failed: pleasure
# spotify audio features query failed: pleasure
# no rating: Harry Styles - Sign of the Times TRACK REVIEW
# no rating: Frank Ocean - Lens ft. Travis Scott TRACK REVIEW
# spotify audio features query failed: drunk
# spotify audio features query failed: drunk
# spotify audio features query failed: drunk
# spotify audio features query failed: drunk
# spotify audio features query failed: drunk
# spotify audio features query failed: drunk
# spotify audio features query failed: drunk
# spotify audio features query failed: the ooz
# spotify audio features query failed: the ooz
# spotify audio features query failed: the ooz
# spotify audio features query failed: the ooz
# spotify audio features query failed: sincerely, future pollution
# spotify audio features query failed: sincerely, future pollution
# spotify audio features query failed: sincerely, future pollution
# spotify audio features query failed: 4eva is a mighty long time
# spotify audio features query failed: 4eva is a mighty long time
# spotify audio features query failed: 4eva is a mighty long time
# invalid title: Radiohead: Worst To Best
# no rating: Portugal. The Man - Woodstock ALBUM REVIEW
# spotify audio features query failed: sleep well beast
# spotify audio features query failed: sleep well beast
# spotify audio features query failed: sleep well beast
# spotify audio features query failed: sleep well beast
# spotify audio features query failed: sleep well beast
# spotify audio features query failed: sleep well beast
# spotify audio features query failed: sleep well beast
# no rating: Wale - Shine ALBUM REVIEW
# spotify audio features query failed: after laughter
# spotify audio features query failed: after laughter
# spotify audio features query failed: after laughter
# spotify audio features query failed: after laughter
# spotify audio features query failed: after laughter
# spotify audio features query failed: howling, for the nightmare shall consume
# spotify audio features query failed: howling, for the nightmare shall consume
# spotify audio features query failed: howling, for the nightmare shall consume
# spotify audio features query failed: howling, for the nightmare shall consume
# spotify audio features query failed: howling, for the nightmare shall consume
# spotify audio features query failed: mareridt
# spotify audio features query failed: mareridt
# spotify audio features query failed: mareridt
# spotify audio features query failed: painted ruins
# spotify audio features query failed: painted ruins
# spotify audio features query failed: painted ruins
# spotify audio features query failed: painted ruins
# spotify audio features query failed: painted ruins
# spotify audio features query failed: painted ruins
# spotify audio features query failed: the thrill of it all
# spotify audio features query failed: the thrill of it all
# spotify audio features query failed: the thrill of it all
# spotify audio features query failed: the thrill of it all
# spotify audio features query failed: the thrill of it all
# spotify audio features query failed: the thrill of it all
# spotify audio features query failed: the thrill of it all
# spotify audio features query failed: as you were
# spotify audio features query failed: as you were
# spotify audio features query failed: as you were
# spotify audio features query failed: as you were
# spotify audio features query failed: as you were
# spotify audio features query failed: as you were
# spotify audio features query failed: as you were
# spotify audio features query failed: as you were
# spotify audio features query failed: narkopop
# spotify audio features query failed: narkopop
# spotify audio features query failed: narkopop
# spotify audio features query failed: narkopop
# spotify audio features query failed: narkopop
# spotify audio features query failed: crack-up
# spotify audio features query failed: crack-up
# spotify audio features query failed: crack-up
# spotify audio features query failed: crack-up
# spotify audio features query failed: crack-up
# spotify audio features query failed: process
# spotify audio features query failed: process
# spotify audio features query failed: process
# not on spotify: drake - more life playlist search term: drake more life playlist
# spotify audio features query failed: i decided
# spotify audio features query failed: i decided
# spotify audio features query failed: i decided
# spotify audio features query failed: i decided
# spotify audio features query failed: i decided
# spotify audio features query failed: i decided
# spotify audio features query failed: i decided
# spotify audio features query failed: why love now
# spotify audio features query failed: still striving
# spotify audio features query failed: still striving
# spotify audio features query failed: still striving
# spotify audio features query failed: still striving
# spotify audio features query failed: still striving
# spotify audio features query failed: still striving
# spotify audio features query failed: still striving
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: self-titled
# spotify audio features query failed: forever
# spotify audio features query failed: material control
# spotify audio features query failed: material control
# spotify audio features query failed: material control
# no rating: Denzel Curry - 13 EP REVIEW
# spotify audio features query failed: black ken
# spotify audio features query failed: black ken
# spotify audio features query failed: black ken
# spotify audio features query failed: black ken
# spotify audio features query failed: black ken
# spotify audio features query failed: black ken
# spotify audio features query failed: black ken
# spotify audio features query failed: black ken
# spotify audio features query failed: black ken
# spotify audio features query failed: black ken
# spotify audio features query failed: black ken
# spotify audio features query failed: black ken
# spotify audio features query failed: black ken
# spotify audio features query failed: add violence
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# C:\Python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# C:\Python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\Python38\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\Python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# C:\Python38\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# C:\Python38\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# C:\Python38\lib\http\client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# C:\Python38\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# C:\Python38\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# C:\Python38\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# C:\Python38\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# C:\Python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     723
# --> 724             retries = retries.increment(
#     725                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# C:\Python38\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     402             if read is False or not self._is_method_retryable(method):
# --> 403                 raise six.reraise(type(error), error, _stacktrace)
#     404             elif read is not None:
#
# C:\Python38\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# C:\Python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# C:\Python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\Python38\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\Python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# C:\Python38\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# C:\Python38\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# C:\Python38\lib\http\client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# C:\Python38\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# C:\Python38\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# C:\Python38\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-29-29361f52e51e> in <module>
#      65
#      66         vid_id = item.id.videoId
# ---> 67         vid = yt.get_video_by_id(video_id=vid_id).items[0]
#      68         description = vid.snippet.description
#      69         vid_title = vid.snippet.title.lower().split(" ")
#
# C:\Python38\lib\site-packages\pyyoutube\api.py in get_video_by_id(self, video_id, parts, hl, max_height, max_width, return_json)
#     817             args["maxWidth"] = max_width
#     818
# --> 819         resp = self._request(resource="videos", method="GET", args=args)
#     820         data = self._parse_response(resp)
#     821
#
# C:\Python38\lib\site-packages\pyyoutube\api.py in _request(self, resource, method, args, post_args, enforce_auth)
#     357
#     358         try:
# --> 359             response = self.session.request(
#     360                 method=method,
#     361                 url=self.BASE_URL + resource,
#
# C:\Python38\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# C:\Python38\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# C:\Python38\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %%
#strategy for scraping data:
#The Needle Drop website has list of reviews which includes tags for rating, as well as genre & artist
#cycle through reviews to get features


#alternatively, cycle through youtube videos with REVIEW keyword and get artist, genre, & rating that way

# %%
#recombine the csvs into a dataframe 


path = './data' # use your path
track_files = glob.glob(path + "/tracks*.csv")
album_files = glob.glob(path + "/albums*.csv")

li = []

for filename in album_files:
    df = pd.read_csv(filename, index_col=0, header=0, dtype=dict(albums.dtypes))
    li.append(df)

album_df = pd.concat(li, axis=0, ignore_index=True)

for filename in track_files:
    df = pd.read_csv(filename, index_col=0, header=0,dtype=dict(tracks.dtypes))
    li.append(df)

track_df = pd.concat(li, axis=0, ignore_index=True)

album_df.to_csv('./data/albums.csv')
track_df.to_csv('./data/tracks.csv')
print(album_df)
print(track_df)

# %%
from keras import Input
from keras.models import Sequential
from keras.layers import Dense

# %%
album_input = keras.Input(shape=(album_input[0].length))
model = Dense(64,activation='relu')(album_input)
model = Dense(256,activation='relu')(model)
model = Dense(256,activation='relu')(model)
output = Dense(10,activation='softmax')
#rough design:
#features:
#artist:
    #transfer to artist id?
#genre
    #encode
#album length (songs & total runtime)
    #tracks scaled to 0-1
#spotify metrics
    #
#mix quality (not sure how to measure)
#number of previous releases
#country of origin


#output: eleven units for rating 0-10
